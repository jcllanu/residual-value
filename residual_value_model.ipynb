# %% [markdown]
# # Residual value model

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %% [markdown]
# ## 1.- Load data

# %%
makes=["acura","audi","bmw","buick","cadillac","chevrolet","chrysler","dodge","ford","gmc","honda","hyundai","infiniti","jeep","kia","land_rover","lexus",
     "lincoln","mazda","mercedes_benz","mini","mitsubishi","nissan","porsche","ram","subaru","tesla","toyota","volkswagen","volvo"]
df_list=[]
for make in makes:
    for batch in range(1,26):
        path='cars\\'+make+'\\cars_'+make+'_'+str(batch)+'.json'
        if os.path.exists(path):
            df_list.append(pd.read_json(path))

df=pd.concat(df_list, ignore_index=True,axis=0)
df.head()
# Out:
#    year_manufacture  years   make  \
# 0              2006     19  acura
# 1              2021      4  acura
# 2              2017      8  acura
# 3              2024      1  acura
# 4              2017      8  acura
#
#                                             model  mileage stock_type  \
# 0                                  Acura TSX Base    76497       Used
# 1                    Acura RDX Technology Package    54931       Used
# 2             Acura MDX 3.5L w/Technology Package   103720       Used
# 3                            Acura Integra A-SPEC    17309       Used
# 4  Acura RDX Technology & AcuraWatch Plus Package    66552       Used
#
#   interior_color         exterior_color        drive_train  \
# 0          Biege            Green Pearl  Front-wheel Drive
# 1       Espresso   Majestic Black Pearl    All-wheel Drive
# 2          Ebony  Modern Steel Metallic    All-wheel Drive
# 3          Ebony   Platinum White Pearl  Front-wheel Drive
# 4          Ebony    White Diamond Pearl    All-wheel Drive
#
#                                                  mpg fuel_type  \
# 0  22–31 Based on EPA mileage ratings. Use for co...  Gasoline
# 1  21–27 Based on EPA mileage ratings. Use for co...  Gasoline
# 2  18–26 Based on EPA mileage ratings. Use for co...  Gasoline
# 3  29–36 Based on EPA mileage ratings. Use for co...  Gasoline
# 4  19–27 Based on EPA mileage ratings. Use for co...  Gasoline
#
#          transmission                                             engine  \
# 0           Automatic  2.4L I-4 DOHC, i-VTEC variable valve control, ...
# 1  10-Speed Automatic  2L I-4 gasoline direct injection, DOHC, VTEC v...
# 2           Automatic  3.5L V-6 gasoline direct injection, i-VTEC var...
# 3           Automatic  1.5L I-4 gasoline direct injection, DOHC, VTEC...
# 4           Automatic  3.5L V-6 i-VTEC variable valve control, premiu...
#
#    price_USD                                                url
# 0    10995.0  https://cars.com/vehicledetail/d6115b1a-3830-4...
# 1    27985.0  https://cars.com/vehicledetail/f9548b93-31b2-4...
# 2    17981.0  https://cars.com/vehicledetail/06e7a2fc-13ec-4...
# 3    30049.0  https://cars.com/vehicledetail/658c133c-dc51-4...
# 4    18950.0  https://cars.com/vehicledetail/79565df9-1fba-4...

# %% [markdown]
# ## 2.- Data Exploration and Preprocesing

# %% [markdown]
# ### 2.1.- Removing duplicates
# Durante el proceso de extracción de datos, pueden surgir duplicidades. Se verifica su existencia y, en caso afirmativo, se eliminan las filas duplicadas del DataFrame.<br> <br>
# During the data extraction process, duplicates may arise. Their presence is verified, and if detected, duplicate rows are removed from the DataFrame.

# %%
num_duplicated_rows=sum(df.duplicated())
print(f'The number of duplicated rows is {num_duplicated_rows}')
# Out:
# The number of duplicated rows is 8982

# %%
df = df.drop_duplicates()
num_duplicated_rows=sum(df.duplicated())
print(f'The number of duplicated rows is now {num_duplicated_rows}')
# Out:
# The number of duplicated rows is now 0

# %% [markdown]
# ### 2.2.- Variable description

# %% [markdown]
# A continuación, se realiza un primer análisis a muy alto nivel de las variables disponibles, utilizando un diccionario de datos y evaluando la cantidad de valores ausentes, valores atípicos o categorías.
#
# #### Diccionario de datos
# - **year_manufacture**: Año de fabricación del vehículo, que generalmente coincide con el año de compra.
# - **years**: Antigüedad del vehículo en años, calculada en 2025. Se obtiene como la diferencia entre el año 2025 y el año de fabricación.
# - **make**: Marca del vehículo.
# - **model**: Modelo del vehículo.
# - **mileage**: Kilometraje del vehículo, expresado en millas.
# - **stock_type**: Indicador de si el vehículo es nuevo o usado.
# - **interior_color**: Color del interior del vehículo, expresado en lenguaje natural.
# - **exterior_color**: Color del exterior del vehículo, expresado en lenguaje natural.
# - **drive_train**: Tipo de tracción del vehículo (delantera, trasera, a las cuatro ruedas).
# - **mpg**: Consumo de combustible, expresado en millas por galón. Puede incluir información sobre la diferencia entre el consumo en ciudad y en carretera.
# - **fuel_type**: Tipo de motorización (diésel, gasolina, híbrido, eléctrico, etc.).
# - **transmission**: Tipo de transmisión. Cadena de texto que indica si es manual o automática y el número de marchas.
# - **engine**: Cadena de caracteres que describe el motor en lenguaje natural. Puede incluir información sobre la cilindrada, el volumen o los caballos.
# - **price_USD**: Precio de venta del vehículo a la fecha de extracción de datos, expresado en dólares estadounidenses.
# - **url**: Dirección web de donde se ha extraído la información.
#
# Datos obtenidos en la página web [Cars.com](https://www.cars.com/) entre los días 22/03/2025 y 28/03/2025 mediante web scraping (ver el [código](https://github.com/jcllanu/residual-value/blob/main/web_scraping.py)).

# %% [markdown]
# Next, a high-level analysis of the available variables is conducted using a data dictionary and assessing the number of missing values, outliers, or categories.
# #### Data dictionary
# - **year_manufacture**: Year of vehicle manufacture, which generally corresponds to the year of purchase.
# - **years**: Vehicle age in years, calculated in 2025. It is obtained as the difference between the year 2025 and the year of manufacture.
# - **make**: Vehicle make.
# - **model**: Vehicle model.
# - **mileage**: Vehicle mileage, expressed in miles.
# - **stock_type**: Indicator of whether the vehicle is new or used.
# - **interior_color**: Interior color of the vehicle, expressed in natural language.
# - **exterior_color**: Exterior color of the vehicle, expressed in natural language.
# - **drive_train**: Vehicle drivetrain type (front, rear, all-wheel drive).
# - **mpg**: Fuel consumption, expressed in miles per gallon. It may include information about the difference between city and highway consumption.
# - **fuel_type**: Engine type (diesel, gasoline, hybrid, electric, etc.).
# - **transmission**: Transmission type. Text string indicating whether it is manual or automatic and the number of gears.
# - **engine**: Text string that describes the engine in natural language. It may include information about the engine displacement and volume.
# - **price_USD**: Vehicle sale price at the data extraction date, expressed in US dollars.
# - **url**: Web address from which the information was extracted.
#
# Data obtained from the website [Cars.com](https://www.cars.com/) between the dates 03/22/2025 and 03/28/2025 using web scraping techniques (see the [code](https://github.com/jcllanu/residual-value/blob/main/web_scraping.py)).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141185 entries, 0 to 150166
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year_manufacture  141185 non-null  int64
#  1   years             141185 non-null  int64
#  2   make              141185 non-null  object
#  3   model             141185 non-null  object
#  4   mileage           141185 non-null  int64
#  5   stock_type        141185 non-null  object
#  6   interior_color    141185 non-null  object
#  7   exterior_color    141185 non-null  object
#  8   drive_train       141185 non-null  object
#  9   mpg               131855 non-null  object
#  10  fuel_type         133860 non-null  object
#  11  transmission      141185 non-null  object
#  12  engine            141185 non-null  object
#  13  price_USD         141181 non-null  float64
#  14  url               141185 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 17.2+ MB

# %% [markdown]
# #### Check the Categorical and Numerical Columns

# %%
# Categorical variables
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical variables:',cat_col)
# Numerical variables
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical variables:',num_col)
# Out:
# Categorical variables: ['make', 'model', 'stock_type', 'interior_color', 'exterior_color', 'drive_train', 'mpg', 'fuel_type', 'transmission', 'engine', 'url']
# Numerical variables: ['year_manufacture', 'years', 'mileage', 'price_USD']

# %%
#Number of unique values for categorical variables
df[cat_col].nunique()
# Out:
# make                  30
# model               9201
# stock_type            26
# interior_color      4507
# exterior_color      5674
# drive_train           17
# mpg                  931
# fuel_type             29
# transmission        1019
# engine              5278
# url               141027
# dtype: int64

# %% [markdown]
# Se observa que algunas variables categóricas presentan una gran variedad de valores distintos, lo cual se debe a que están expresadas en lenguaje natural. Será necesario aplicar un procesamiento de datos riguroso para tratarlas adecuadamente.

# %% [markdown]
# It is observed that some categorical variables exhibit a wide range of distinct values, which is due to their expression in natural language. A thorough data processing approach will be required to handle them appropriately.

# %%
for col in cat_col:
    print('Variable:',col)
    print('Sample of some unique values:', df[col].unique()[:20],'\n')
# Out:
# Variable: make
# Sample of some unique values: ['acura' 'audi' 'bmw' 'buick' 'cadillac' 'chevrolet' 'chrysler' 'dodge'
#  'ford' 'gmc' 'honda' 'hyundai' 'infiniti' 'jeep' 'kia' 'land_rover'
#  'lexus' 'lincoln' 'mazda' 'mercedes_benz']
#
# Variable: model
# Sample of some unique values: ['Acura TSX Base' 'Acura RDX Technology Package'
#  'Acura MDX 3.5L w/Technology Package' 'Acura Integra A-SPEC'
#  'Acura RDX Technology & AcuraWatch Plus Package' 'Acura TLX V6 Tech'
#  'Acura Integra A-SPEC w/ Technology' 'Acura TLX V6' 'Acura ZDX A-SPEC'
#  'Acura MDX Sport Hybrid SH-AWD Sport Hybrid w/Technology Pkg'
#  'Acura RLX Technology Package' 'Acura MDX SH-AWD Technology'
#  'Acura TLX Base' 'Acura MDX SH-AWD' 'Acura ZDX A-Spec'
#  'Acura RDX SH-AWD Technology' 'Acura MDX Sport Hybrid Technology Package'
#  'Acura TSX Technology' 'Acura ILX Base' 'Acura MDX 3.5L']
#
# Variable: stock_type
# Sample of some unique values: ['Used' 'Acura Certified' 'Certified' 'Audi Certified' 'BMW Certified'
#  'Buick Certified' 'Cadillac Certified' 'Chevrolet Certified'
#  'Chrysler Certified' 'Dodge Certified' 'Ford Certified' 'GMC Certified'
#  'Honda Certified' 'Hyundai Certified' 'INFINITI Certified'
#  'Jeep Certified' 'Kia Certified' 'Lincoln Certified'
#  'Mercedes-Benz Certified' 'Mitsubishi Certified']
#
# Variable: interior_color
# Sample of some unique values: ['Biege' 'Espresso' 'Ebony' 'Gray' '–' 'Red' 'BLACK' 'BROWN' 'Black' 'RED'
#  'No Color' 'GRAY' 'Graystone' 'Tan' 'Taupe Leather' 'Parchment'
#  'Ebony w/Premium Leather-Trimmed Interior' 'Umber' 'Graphite' 'Quartz']
#
# Variable: exterior_color
# Sample of some unique values: ['Green Pearl' 'Majestic Black Pearl' 'Modern Steel Metallic'
#  'Platinum White Pearl' 'White Diamond Pearl' 'Gray'
#  'Graphite Luster Metallic' 'Liquid Carbon Metallic'
#  'Bellanova White Pearl' 'Mercury Silver Metallic' 'BLACK' 'Black' 'White'
#  'Performance Red Pearl' 'Lunar Silver Metallic' 'Brown'
#  'pewter gray metallic' 'Crystal Black Pearl' 'Basque Red Pearl II'
#  'Silver']
#
# Variable: drive_train
# Sample of some unique values: ['Front-wheel Drive' 'All-wheel Drive' 'Four-wheel Drive'
#  'Rear-wheel Drive' '–' 'FWD' 'AWD' '4WD' '2WD' 'Unknown' 'RWD'
#  'All Wheel Drive' 'Four Wheel Drive' 'Front Wheel Drive' '4x4'
#  'All-Wheel Drive' 'Front-Wheel Drive']
#
# Variable: mpg
# Sample of some unique values: ['22–31 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '21–27 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '18–26 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '29–36 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '19–27 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '29–29 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '21–34 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  None
#  '26–27 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '20–31 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '19–25 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '20–30 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '26–36 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '19–26 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '21–30 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '24–34 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '20–29 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '20–28 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '18–27 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.'
#  '19–0 Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.']
#
# Variable: fuel_type
# Sample of some unique values: ['Gasoline' None 'Hybrid' '–' 'E85 Flex Fuel' 'Gas' 'Plug-In Hybrid'
#  'Diesel' 'Flexible Fuel' 'Gasoline / Natural Gas' 'Gasoline fuel type'
#  'Gasoline/Mild Electric Hybrid' 'Plug-in Gas/Electric Hybrid' 'Other'
#  'Diesel (B20 capable)' 'Unspecified' 'Gaseous' 'Flex'
#  'Plug-In Hybrid Fuel' 'Regular Unleaded']
#
# Variable: transmission
# Sample of some unique values: ['Automatic' '10-Speed Automatic' 'Automatic 5-Speed' '9-Speed Automatic'
#  'CVT' 'Manual' '6-Speed Automatic' 'Variable' 'Automatic 6-Speed'
#  '5-Speed Automatic' '8-Speed Automatic with Auto-Shift'
#  'Automatic, 9-Spd w/Sequential SportShift' '7-Speed Automatic'
#  '5-Speed Automatic with Sequential SportShift' 'A/T'
#  '5-Speed Shiftable Automatic' '7-Speed Automatic with Auto-Shift'
#  '1-Speed Automatic' '6 Speed Auto' '5-Speed A/T']
#
# Variable: engine
# Sample of some unique values: ['2.4L I-4 DOHC, i-VTEC variable valve control, premium unleaded,'
#  '2L I-4 gasoline direct injection, DOHC, VTEC variable valve cont'
#  '3.5L V-6 gasoline direct injection, i-VTEC variable valve contro'
#  '1.5L I-4 gasoline direct injection, DOHC, VTEC variable valve co'
#  '3.5L V-6 i-VTEC variable valve control, premium unleaded, engine'
#  '2.4L I4' '3.5L V6 24V GDI SOHC'
#  '3.5L V-6 gasoline direct injection, variable valve control, prem'
#  'Electric ZEV 490hp'
#  '3.0L PGM-FI 24V SOHC i-VTEC V6 -inc: Variable Cylinder Managemen' 'Gas'
#  '2.0L I4 16V GDI DOHC Turbo' '3.5L V6 SOHC 24V' 'Electric' 'Turbo Gas'
#  '3L V-6 i-VTEC variable valve control, premium unleaded, engine w'
#  '2.4L I-4 gasoline direct injection, DOHC, i-VTEC variable valve'
#  '3.5L V6 24V MPFI SOHC'
#  '3.2L V-6 variable valve control, premium unleaded, engine with 2'
#  '3.5L V-6 variable valve control, premium unleaded, engine with 2']
#
# Variable: url
# Sample of some unique values: ['https://cars.com/vehicledetail/d6115b1a-3830-4d7b-9421-984712e65046/'
#  'https://cars.com/vehicledetail/f9548b93-31b2-4d3b-b1c6-890629058be0/'
#  'https://cars.com/vehicledetail/06e7a2fc-13ec-4754-ae04-ede86a7c586f/'
#  'https://cars.com/vehicledetail/658c133c-dc51-4137-91bd-f8a8b482c3cf/'
#  'https://cars.com/vehicledetail/79565df9-1fba-4259-aef4-45356dc30cc7/'
#  'https://cars.com/vehicledetail/6a70c9e2-6ae4-48f3-bc8e-e5aecb430c18/'
#  'https://cars.com/vehicledetail/f2ab0f08-372a-47c7-8102-d2186a3cf7a7/'
#  'https://cars.com/vehicledetail/49da1593-a6bb-490b-aa34-203e411c5125/'
#  'https://cars.com/vehicledetail/04e574ec-2f3a-4c02-9d04-d7f825274f58/'
#  'https://cars.com/vehicledetail/d2ab96b2-123e-444e-a1e0-c678f57709aa/'
#  'https://cars.com/vehicledetail/95d932a8-e17e-459d-8e7e-9e6a258d87c5/'
#  'https://cars.com/vehicledetail/a7e81109-9fb3-45ec-8dcb-f640e2eb370d/'
#  'https://cars.com/vehicledetail/c5e575cf-0d03-4c82-933b-23b34e8bcde1/'
#  'https://cars.com/vehicledetail/1863a2c4-e6e3-43d7-b24b-43a7f2a05d23/'
#  'https://cars.com/vehicledetail/0ae63d46-075f-44c3-881c-f15b95fbae7c/'
#  'https://cars.com/vehicledetail/d5837d12-6c65-4c75-ac2e-52ee47c74741/'
#  'https://cars.com/vehicledetail/acf3592a-13ec-4899-be96-9617e6ca2031/'
#  'https://cars.com/vehicledetail/026faf23-8fa3-46c5-b69f-83ebdef441c9/'
#  'https://cars.com/vehicledetail/748ad76d-60fd-4425-b056-f13aaff6f60e/'
#  'https://cars.com/vehicledetail/f779a2de-4210-472b-87cc-9d6764da9273/']

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# ##### MPG

# %% [markdown]
# Se puede observar que este campo está compuesto por un par de valores numéricos separados por un guion, seguidos de una nota informativa: 'Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.' Asumiremos que, en producción, se contará con los 'EPA mileage ratings' de los vehículos, por lo que esta variable puede seguir siendo útil. De ella, obtendremos los valores de consumo en ciudad y carretera si están disponibles.

# %% [markdown]
# It can be observed that this field consists of a pair of numerical values separated by a hyphen, followed by an informational note: 'Based on EPA mileage ratings. Use for comparison purposes only. Actual mileage will vary depending on driving conditions, driving habits, vehicle maintenance, and other factors.' We will assume that, in production, the 'EPA mileage ratings' of the vehicles will be available, so this variable may still be useful. From it, we will obtain the values for city and highway consumption if available.

# %%
def keep_numbers_and_en_dash(text):
    if text is None:
        return None  # Return None if the value is None
    return re.sub(r'[^0-9–]', '', text)  # Keep numbers and en dash (–)

def get_mpg_city(text):
    if text is None:
        return None  # Return None if the value is None
    if text == "–":
        return None # No information available
    if "–" not in text:
        return float(text) if text.replace('.', '', 1).isdigit() and text.count('.') < 2 \
            else None # If the text is a decimal number, return the number
    return float(text.split('–')[0]) if text.split('–')[0].replace('.', '', 1).isdigit() \
        and text.split('–')[0].count('.') < 2 else None # Since the text contains an hyphen, 
                                                        # return what's on the left-hand
                                                        # side if it is a decimal number

def get_mpg_highway(text):
    if text is None:
        return None  # Return None if the value is None
    if text == "–":
        return None # No information available
    if "–" not in text:
        return float(text) if text.replace('.', '', 1).isdigit() and text.count('.') < 2 \
            else None # If the text is a decimal number, return the number
    return float(text.split('–')[1]) if text.split('–')[1].replace('.', '', 1).isdigit() \
        and text.split('–')[1].count('.') < 2 else None # Since the text contains an hyphen, 
                                                        # return what's on the right-hand
                                                        # side if it is a decimal number

df.loc[df['mpg'].apply(lambda x: isinstance(x, float) and np.isnan(x)),'mpg']=None # substitue NaN for None
df['auxiliar'] = df['mpg'].apply(keep_numbers_and_en_dash)
df['mpg_city'] = df['auxiliar'].apply(get_mpg_city)
df['mpg_highway'] = df['auxiliar'].apply(get_mpg_highway)

# %%
# Check nulls in mpg_city: All null values in mpg_city are due to the fact that mpg is None or '–'
df[df['mpg_city'].isnull()]['mpg'].unique()
# Out:
# array([None, '–'], dtype=object)

# %%
# Check nulls in mpg_highway: All null values in mpg_highway are due to the fact that mpg is None or '–'
df[df['mpg_highway'].isnull()]['mpg'].unique()
# Out:
# array([None, '–'], dtype=object)

# %%
# Remove useless colums and display the df
df.drop(columns=['mpg', 'auxiliar'], inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  \
# 0              2006     19  acura
# 1              2021      4  acura
# 2              2017      8  acura
# 3              2024      1  acura
# 4              2017      8  acura
#
#                                             model  mileage stock_type  \
# 0                                  Acura TSX Base    76497       Used
# 1                    Acura RDX Technology Package    54931       Used
# 2             Acura MDX 3.5L w/Technology Package   103720       Used
# 3                            Acura Integra A-SPEC    17309       Used
# 4  Acura RDX Technology & AcuraWatch Plus Package    66552       Used
#
#   interior_color         exterior_color        drive_train fuel_type  \
# 0          Biege            Green Pearl  Front-wheel Drive  Gasoline
# 1       Espresso   Majestic Black Pearl    All-wheel Drive  Gasoline
# 2          Ebony  Modern Steel Metallic    All-wheel Drive  Gasoline
# 3          Ebony   Platinum White Pearl  Front-wheel Drive  Gasoline
# 4          Ebony    White Diamond Pearl    All-wheel Drive  Gasoline
#
#          transmission                                             engine  \
# 0           Automatic  2.4L I-4 DOHC, i-VTEC variable valve control, ...
# 1  10-Speed Automatic  2L I-4 gasoline direct injection, DOHC, VTEC v...
# 2           Automatic  3.5L V-6 gasoline direct injection, i-VTEC var...
# 3           Automatic  1.5L I-4 gasoline direct injection, DOHC, VTEC...
# 4           Automatic  3.5L V-6 i-VTEC variable valve control, premiu...
#
#    price_USD                                                url  mpg_city  \
# 0    10995.0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0
# 1    27985.0  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0
# 2    17981.0  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0
# 3    30049.0  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0
# 4    18950.0  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0
#
#    mpg_highway
# 0         31.0
# 1         27.0
# 2         26.0
# 3         36.0
# 4         27.0

# %% [markdown]
# #### Transmission

# %% [markdown]
# De esta columna, queremos derivar otras dos columna: una que nos indique el tipo de transmisión (automática, manual, [manumática](https://es.wikipedia.org/wiki/Transmisi%C3%B3n_manum%C3%A1tica), [variable](https://es.wikipedia.org/wiki/Transmisi%C3%B3n_variable_continua) o [dual-clutch](https://es.wikipedia.org/wiki/Caja_de_cambios_de_doble_embrague) ), y otra que nos indique el número de marchas del vehículo.

# %% [markdown]
# From this column, we want to derive two other columns: one indicating the type of transmission (automatic, manual, [manumatic](https://en.wikipedia.org/wiki/Manumatic), [variable](https://en.wikipedia.org/wiki/Continuously_variable_transmission), or [dual-clutch](https://en.wikipedia.org/wiki/Dual-clutch_transmission)), and another indicating the number of gears/speeds of the vehicle.

# %%
def get_speeds_of_transmission(text):
    if text is None:
        return None  # Return None if the value is None
    
    # Check some particular cases individually
    if "SINGLE" in text.upper():
        return 1
    if "TWO" in text.upper():
        return 1
    if text in ('4L80E', '4l60e'):
        return 4
    if text in ('TH400', 'TH350', 'TH 400'):
        return 3
    if text == '6L70E':
      return 6

    # The general logic of the strings is that the first 
    # number of the string identifies the number of speeds
    substring = re.sub(r'[^0-9]', '', text) #Obtain the numbers in the text
    if substring=="":
        return None # Unable to identify the number of speeds
    if len(substring)==1:
        return int(substring) # return the number if it has 1 digit
    if len(substring)>=2:
        if substring[0]=="1":
            if int(substring)==10006: # The general doesn't apply for 'Allison 1000 6-Speed Automatic' 
                return 6
            if int(substring)==1503: # nor 'Borg-Warner T150 3 Speed Manual'
                return 3
            return int(substring) # Surprisingly, there are cars with 10 or more speeds
        else:
            return int(substring[0]) #If there are more than 2 digits, return the first one
    return None

def keep_letters(text):
    return re.sub(r'[^a-zA-Z]', '', text) #Auxiliar function to obtain just the letters of a string

def get_transmission_type(text):
    # General cases in which the transmission type is explicitly stated combined with
    # particular cases in which it has to be derived from the commercial name of the 
    # transmission 

    if "MANUAL" in text.upper() or "M/T" in text.upper() or "SMG" in text.upper(): # SMG for bmw
        return "Manual"
    
    if "AUTO" in text.upper() or "A/T" in text.upper() \
    or keep_letters(text).upper()=='A' or "AU" in text.upper() or "AT" in text.upper()\
    or '6L80' in text.upper() or " A" in text.upper() or "ZF" in text.upper() \
    or 'ECT' in text.upper() or text in ('4L80E','TH400', 'TH350', 'TH 400', \
    '4l60e', '6L70E', 'EFLITE SI-EVT', 'E4OD 4R100', '8HP75'): #ZF and 8HP75 for bmw, ECT for toyota, 4L80E, 
    # 6L70E,6L80, 4l60e for GM group, TH350 and TH400 for chevrolet and buick, EFLITE SI-EVT chrysler
        return "Automatic"
    
    if "VARIABLE" in text.upper() or "CVT" in text.upper() or text in ('i-VT', 'IVT'): 
        #Continuously Variable Transmission, ivt for hyundai
        return "Variable"
    
    if "DUAL" in text.upper() or "DOUBLE" in text.upper() or "DC" in text.upper() \
        or "S TRONIC" in text.upper() or "S-TRONIC" in text.upper() \
        or "PDK" in text.upper(): # Dual-Clutch Transmission (DCT), stronic for audi, PDK for Porsche
        return "Dual-clutch"
    
    if "GEARTRONIC" in text.upper() or "SHIFTRONIC" in text.upper() \
    or "STEPTRONIC" in text.upper() or "TRIPTONIC" in text.upper() \
    or "TIPTRONIC" in text.upper() or "SPORTRONIC" in text.upper(): 
        #Geartronic for volvo, steptronic for bmw, Tiptronic for 
        # volkswagen group, sportronic for Mitsubishi
        return "Manumatic"
    return None

df['num_speeds']=df['transmission'].apply(get_speeds_of_transmission)
df['transmission_type']=df['transmission'].apply(get_transmission_type)

# %%
# Check nulls in transmission_type: All null values in transmission_type are due to the fact that transmission variable doesn't give any clue of the transmission type
df[df['transmission_type'].isnull()]['transmission'].unique()
# Out:
# array(['Not Specified', '9-Speed', 'Single-speed transmission', '7 speed',
#        '–', '6-Speed', '5-Speed', 'Single Speed', '3-Speed',
#        'Transmission Overdrive Switch', 'Single-Speed Fixed Gear',
#        'Single Reduction Gear', 'Unspecified', '10 Speed', 'Sequential',
#        'SINGLE-SPEED TRANSMISSION', '10-SPEED TRANSMISSION',
#        'NOT SPECIFIED', '448', '8', 'Standard', '8-Speed',
#        'Single-Speed Reduction Gear', 'DFT', 'Single-Speed Fi', 'Other',
#        '15S', 'MOD HYBRID TRANSMISSION', 'N/A',
#        '6-Spd Sport Transmission', '5SP', '5 Speed',
#        'Continuously Variabl', '9SP', 'Single Speed Reducer', '5M',
#        '7-Speed', 'standard', '6 Speed', 'Single Speed Transmission', 'C',
#        'SINGLE-SPEED FIXED GEAR', 'Single-Speed Fixed Gear Transmission',
#        '4 Speed Transmission', '1-SPEED G', 'AWD', 'FWD', 'Drivetrai'],
#       dtype=object)

# %%
# Check nulls in num_speeds: All null values in num_speeds are due to the fact that transmission variable doesn't explicitly indicate the number of gears/speeds
df[df['num_speeds'].isnull()]['transmission'].unique()
# Out:
# array(['Automatic', 'CVT', 'Manual', 'Variable', 'A/T',
#        'Transmission w/Dual Shift Mode', 'Automatic CVT',
#        'Continuously Variable Transmission', 'Not Specified',
#        'Automatic w/OD', 'Auto-Shift Manual', 'CVT Transmission',
#        'Continuously Variable', 'Transmission-Auto', 'AUTO',
#        'Automatic with Tiptronic', 'quattroa? s tronica?', 'M/T',
#        'quattroA? S tronicA?', 'quattroA? TiptronicA?', 'A', 'AUTOMATIC',
#        'quattro, s-tronic', 'Automatic w/Tiptronic', '–',
#        'quattro S tronic', 'CVT with Multitronic', 'FWD, s-tronic',
#        'Auto, CVT Multitronic', 'Auto', 'Automatic w/Steptronic', 'auto',
#        'Steptronic', 'Automatic w/Manual Shift', 'DCT',
#        'STEPTRONIC AUTOMATIC', 'automatic', 'Automatic Automatic',
#        'Dynaflow  Automatic', 'Automatic, CVT', 'AT',
#        'Continuously Variable (CVT)', 'CONTINUOUSLY VARIABLE (CVT)',
#        'AUTO Automatic', 'Transmission Overdrive Switch', 'CVT Automatic',
#        'manual', 'Unspecified', 'CVT with Xtronic', 'EFLITE SI-EVT',
#        'Auto, eFlite EVT', 'eFlite Electrically Variable',
#        'Automatic, eFlite EVT', 'EFlite CVT', 'Sequential', 'eCVT',
#        'E-CVT Automatic', 'CONTINUOUSLY VARIABLE',
#        'Cruise-o-matic Automatic', 'ELECTRONICALLY CONTROLLED (ECVT)',
#        'ELEC TEN-SPEED AUTO W/TOW M', 'NOT SPECIFIED', 'Automatic, eCVT',
#        'Ford-O-Matic Automatic', 'Electronically Controlled Automatic',
#        'Automatic with Overdrive', 'Auto, CVT w/Sport Mode',
#        'Auto, CVT G-Shft Ctrl', 'CVT w/OD',
#        'continuously variable automatic',
#        'Automatic, CVT w/G-Shift Control', 'AUTOMATIC, CVT', 'Standard',
#        'Auto-Shift Manual w/OD', 'Shiftronic', 'Automatic, IVT',
#        'INTELLIGENT VARIABLE (IVT) -INC: GATE-TYPE, SHIFTRONIC AND HILL',
#        'Automatic, IVT w/Shiftronic', 'ALTOMATIC', 'Sport-Tuned CVT',
#        'Automatic, CVT w/Manual Mode', 'AUTO, CVT MANUAL SPT MODE',
#        'Auto, CVT Manual Spt', 'Automatic, Xtronic CVT', 'Xtronic CVT',
#        'Select', 'DFT', 'Automatic, i-VT', 'Automatic, i-CVT', 'i-VT',
#        'IVT',
#        'INTELLIGENT VARIABLE (IVT) -INC: DRIVE MODE SELECT (NORMAL, ECO',
#        'Transmission-Manual', 'Other', 'Continuously Variable (ECVT)',
#        'Automatic, ECVT', 'Aisin e-CVT Powersplit',
#        'FHEV/PHEV AUTO TRANSMISSION', 'MOD HYBRID TRANSMISSION',
#        'E-CVT AUTO TRANS PWRSPLT', 'AUTOMATIC TRANSMISSION',
#        'Steptronic Automatic', 'N/A', 'Automatic, CVT w/Sportronic',
#        'Automatic, CVT w/Sport Mode', 'Automatic CVT with Sportronic',
#        'CVT with Sportronic', 'CVT Sportronic with Paddle-Shifters',
#        'AUTOMATIC CVT', 'Automatic CVT w/Sport Mode',
#        'Continuously Variabl',
#        'Continuously Variable (CVT) -inc: Sportronic',
#        'Automatic Xtronic CVT', 'Continuously variable-speed automatic',
#        'Automatic, CVT w/Xtronic', 'Automatic, CVT w/S-Mode', 'MANUAL',
#        'Auto, CVT Xtronic', 'Auto, Xtronic CVT', 'PDK', 'PDK Dual Clutch',
#        'PDK Automatic', 'Tiptronic', 'standard', 'TipTronic',
#        'Automatic, PDK', 'CVT Lineartronic', 'Lineartronic CVT',
#        'Auto, CVT Manual', 'Auto, CVT Manual Mode',
#        'Automatic, CVT w/Lineartronic', 'Auto, CVT w/Manual Mode',
#        'Auto, CVT Lnrtrnc Manual', 'Auto, CVT w/Lineartronic',
#        'Auto, CVT Lineartronic',
#        'Automatic, CVT w/Lineartronic & Manual Modes',
#        'CVT w/Sequential Shift Mode', 'C', 'Automatic, CVTi',
#        'Automatic, CVTi-S', 'Automatic/CVT', 'DSG Automatic', 'SMG other',
#        'Manual Manual', 'Automatic with Geartronic', 'AWD', 'FWD',
#        'Drivetrai'], dtype=object)

# %%
df.drop(columns=['transmission'], inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  \
# 0              2006     19  acura
# 1              2021      4  acura
# 2              2017      8  acura
# 3              2024      1  acura
# 4              2017      8  acura
#
#                                             model  mileage stock_type  \
# 0                                  Acura TSX Base    76497       Used
# 1                    Acura RDX Technology Package    54931       Used
# 2             Acura MDX 3.5L w/Technology Package   103720       Used
# 3                            Acura Integra A-SPEC    17309       Used
# 4  Acura RDX Technology & AcuraWatch Plus Package    66552       Used
#
#   interior_color         exterior_color        drive_train fuel_type  \
# 0          Biege            Green Pearl  Front-wheel Drive  Gasoline
# 1       Espresso   Majestic Black Pearl    All-wheel Drive  Gasoline
# 2          Ebony  Modern Steel Metallic    All-wheel Drive  Gasoline
# 3          Ebony   Platinum White Pearl  Front-wheel Drive  Gasoline
# 4          Ebony    White Diamond Pearl    All-wheel Drive  Gasoline
#
#                                               engine  price_USD  \
# 0  2.4L I-4 DOHC, i-VTEC variable valve control, ...    10995.0
# 1  2L I-4 gasoline direct injection, DOHC, VTEC v...    27985.0
# 2  3.5L V-6 gasoline direct injection, i-VTEC var...    17981.0
# 3  1.5L I-4 gasoline direct injection, DOHC, VTEC...    30049.0
# 4  3.5L V-6 i-VTEC variable valve control, premiu...    18950.0
#
#                                                  url  mpg_city  mpg_highway  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0         31.0
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0         27.0
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0         26.0
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0         36.0
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0         27.0
#
#    num_speeds transmission_type
# 0         NaN         Automatic
# 1        10.0         Automatic
# 2         NaN         Automatic
# 3         NaN         Automatic
# 4         NaN         Automatic

# %% [markdown]
# Más adelante se abordará el tratamiento de los valores faltantes y la imputación correspondiente. No obstante, antes de ello, se puede observar que la mayoría de los valores ausentes en la variable num_speeds se concentra en los vehículos identificados como automáticos, lo cual resulta coherente.

# %% [markdown]
# The treatment of missing values and the corresponding imputation will be addressed later. However, prior to that, it can be observed that most of the missing values in the num_speeds variable are concentrated in vehicles identified as automatic, which is logically consistent.

# %%
df.groupby(['transmission_type','num_speeds'], dropna=False).size().reset_index(name='Count')
# Out:
#    transmission_type  num_speeds  Count
# 0          Automatic         1.0   2944
# 1          Automatic         2.0    177
# 2          Automatic         3.0     77
# 3          Automatic         4.0   1122
# 4          Automatic         5.0   1571
# 5          Automatic         6.0   9985
# 6          Automatic         7.0   3884
# 7          Automatic         8.0  15761
# 8          Automatic         9.0   6306
# 9          Automatic        10.0   4438
# 10         Automatic         NaN  83465
# 11       Dual-clutch         6.0     50
# 12       Dual-clutch         7.0    244
# 13       Dual-clutch         8.0    203
# 14       Dual-clutch         NaN    262
# 15            Manual         2.0      1
# 16            Manual         3.0     21
# 17            Manual         4.0    104
# 18            Manual         5.0    432
# 19            Manual         6.0   1895
# 20            Manual         7.0    111
# 21            Manual         8.0     41
# 22            Manual         NaN   3032
# 23         Manumatic         5.0      1
# 24         Manumatic         6.0      1
# 25         Manumatic         8.0      6
# 26         Manumatic         NaN     43
# 27          Variable         0.0      1
# 28          Variable         1.0     25
# 29          Variable         4.0      1
# 30          Variable         6.0     30
# 31          Variable         7.0     43
# 32          Variable         8.0     57
# 33          Variable        10.0      1
# 34          Variable         NaN   4189
# 35               NaN         1.0     94
# 36               NaN         3.0      1
# 37               NaN         4.0      2
# 38               NaN         5.0     18
# 39               NaN         6.0     66
# 40               NaN         7.0     29
# 41               NaN         8.0      3
# 42               NaN         9.0      4
# 43               NaN        10.0      3
# 44               NaN        15.0      1
# 45               NaN         NaN    440

# %% [markdown]
# #### Drive train

# %% [markdown]
# El tratamiento propuesto para esta variable consiste en reducir el conjunto de posibles valores a tres categorías: tracción delantera, tracción trasera y tracción a las cuatro ruedas.

# %% [markdown]
# The proposed treatment for this variable involves reducing the range of possible values to three categories: front-wheel drive, rear-wheel drive, and all-wheel drive.

# %%
def get_drive_train(text):
    if "FRONT" in text.upper() or 'FWD' == text:
        return "Front-wheel Drive"
    if "ALL" in text.upper() or "FOUR" in text.upper() or '4' in text or 'AWD'==text:
        return "All-wheel Drive"
    if "REAR" in text.upper() or 'RWD'==text:
        return "Rear-wheel Drive"
    return None
df['drive_train_v2']=df['drive_train'].apply(get_drive_train)

# %%
# Check nulls in drive_train_v2: All null values in drive_train_v2 are due to the fact that drive_train variable doesn't provide the information
df[df['drive_train_v2'].isnull()]['drive_train'].unique()
# Out:
# array(['–', '2WD', 'Unknown'], dtype=object)

# %%
# We remove the original variable and substitute it for the processed one
df.drop(columns=['drive_train'], inplace=True)
df.rename(columns={'drive_train_v2': 'drive_train'}, inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  \
# 0              2006     19  acura
# 1              2021      4  acura
# 2              2017      8  acura
# 3              2024      1  acura
# 4              2017      8  acura
#
#                                             model  mileage stock_type  \
# 0                                  Acura TSX Base    76497       Used
# 1                    Acura RDX Technology Package    54931       Used
# 2             Acura MDX 3.5L w/Technology Package   103720       Used
# 3                            Acura Integra A-SPEC    17309       Used
# 4  Acura RDX Technology & AcuraWatch Plus Package    66552       Used
#
#   interior_color         exterior_color fuel_type  \
# 0          Biege            Green Pearl  Gasoline
# 1       Espresso   Majestic Black Pearl  Gasoline
# 2          Ebony  Modern Steel Metallic  Gasoline
# 3          Ebony   Platinum White Pearl  Gasoline
# 4          Ebony    White Diamond Pearl  Gasoline
#
#                                               engine  price_USD  \
# 0  2.4L I-4 DOHC, i-VTEC variable valve control, ...    10995.0
# 1  2L I-4 gasoline direct injection, DOHC, VTEC v...    27985.0
# 2  3.5L V-6 gasoline direct injection, i-VTEC var...    17981.0
# 3  1.5L I-4 gasoline direct injection, DOHC, VTEC...    30049.0
# 4  3.5L V-6 i-VTEC variable valve control, premiu...    18950.0
#
#                                                  url  mpg_city  mpg_highway  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0         31.0
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0         27.0
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0         26.0
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0         36.0
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0         27.0
#
#    num_speeds transmission_type        drive_train
# 0         NaN         Automatic  Front-wheel Drive
# 1        10.0         Automatic    All-wheel Drive
# 2         NaN         Automatic    All-wheel Drive
# 3         NaN         Automatic  Front-wheel Drive
# 4         NaN         Automatic    All-wheel Drive

# %% [markdown]
# #### Stock type

# %% [markdown]
# El tratamiento propuesto para esta variable consiste en agrupar los valores posibles en tres categorías: usado, nuevo y certificado.
#
# 1.- Inspeccionado – Ha pasado una inspección detallada de múltiples puntos (a menudo entre 100 y más de 200 elementos) realizada por el fabricante o el concesionario.
#
# 2.- Reacondicionado o restaurado – Cualquier problema encontrado durante la inspección ha sido corregido para cumplir con ciertos estándares de calidad.
#
# 3.- Respaldado por una garantía – Viene con una garantía extendida del fabricante o del concesionario, a menudo más allá de la garantía original de fábrica.
#
# 4.- Generalmente más nuevo y con menor kilometraje – Los autos certificados suelen tener una antigüedad limitada (por ejemplo, menos de 5 años) y un kilometraje restringido (por ejemplo, menos de 60,000 km).
#
# Si bien la condición de stock no es una característica intrínseca del vehículo que pueda incluirse como variable en el modelo —ya que todos los datos de entrada corresponderán a vehículos nuevos y no es posible anticipar si, con el tiempo, pasarán a ser certificados—, no es necesario excluir los vehículos certificados del conjunto de datos históricos para la construcción del modelo.

# %% [markdown]
# The proposed treatment for this variable involves grouping the possible values into three categories: used, new, and certified. Certified vehicles are typically characterized by the following:
#
# 1.- Thorough inspection: They have undergone a detailed multi-point inspection (often covering 100 to over 200 items) performed by the manufacturer or dealership.
#
# 2.- Reconditioning or restoration: Any issues identified during the inspection have been addressed to meet specific quality standards.
#
# 3.- Extended warranty: They come with an additional warranty provided by the manufacturer or dealership, often extending beyond the original factory warranty.
#
# 4.- Generally newer and with lower mileage: Certified vehicles typically have limited age (e.g., less than 5 years) and mileage (e.g., under 60,000 miles).
#
# Although stock status is not an intrinsic characteristic of the vehicle and therefore cannot be included as a model input—since all inputs will represent new vehicles, and it's not possible to know in advance whether they will later qualify as certified—it is not necessary to exclude certified vehicles from the historical dataset used to train the model.

# %%
def stock_type(text):
    if "CERTIFIED" in text.upper():
        return "Certified"
    if "USED" in text.upper():
        return "Used"
    if "NEW" in text.upper():
        return "New"
    return None

df['stock_type_v2']=df['stock_type'].apply(stock_type)
df['stock_type_v2'].unique()
# Out:
# array(['Used', 'Certified'], dtype=object)

# %%
# We remove the original variable and substitute it for the processed one
df.drop(columns=['stock_type'], inplace=True)
df.rename(columns={'stock_type_v2': 'stock_type'}, inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  \
# 0              2006     19  acura
# 1              2021      4  acura
# 2              2017      8  acura
# 3              2024      1  acura
# 4              2017      8  acura
#
#                                             model  mileage interior_color  \
# 0                                  Acura TSX Base    76497          Biege
# 1                    Acura RDX Technology Package    54931       Espresso
# 2             Acura MDX 3.5L w/Technology Package   103720          Ebony
# 3                            Acura Integra A-SPEC    17309          Ebony
# 4  Acura RDX Technology & AcuraWatch Plus Package    66552          Ebony
#
#           exterior_color fuel_type  \
# 0            Green Pearl  Gasoline
# 1   Majestic Black Pearl  Gasoline
# 2  Modern Steel Metallic  Gasoline
# 3   Platinum White Pearl  Gasoline
# 4    White Diamond Pearl  Gasoline
#
#                                               engine  price_USD  \
# 0  2.4L I-4 DOHC, i-VTEC variable valve control, ...    10995.0
# 1  2L I-4 gasoline direct injection, DOHC, VTEC v...    27985.0
# 2  3.5L V-6 gasoline direct injection, i-VTEC var...    17981.0
# 3  1.5L I-4 gasoline direct injection, DOHC, VTEC...    30049.0
# 4  3.5L V-6 i-VTEC variable valve control, premiu...    18950.0
#
#                                                  url  mpg_city  mpg_highway  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0         31.0
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0         27.0
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0         26.0
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0         36.0
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0         27.0
#
#    num_speeds transmission_type        drive_train stock_type
# 0         NaN         Automatic  Front-wheel Drive       Used
# 1        10.0         Automatic    All-wheel Drive       Used
# 2         NaN         Automatic    All-wheel Drive       Used
# 3         NaN         Automatic  Front-wheel Drive       Used
# 4         NaN         Automatic    All-wheel Drive       Used

# %% [markdown]
# #### Vehicle model

# %% [markdown]
# A simple vista, se observa que el nombre de los modelos contiene un nivel de detalle excesivo, lo que puede dificultar la capacidad del modelo de aprendizaje automático para generalizar adecuadamente. Por ello, se propone reducir el conjunto de posibles valores de la variable model para cada marca a una lista elaborada con criterio experto, garantizando que todo modelo reciba una nueva clasificación. Es decir, para dos modelos como 'Acura RDX Technology Package' y 'Acura RDX Technology & AcuraWatch Plus Package', ambos, con make='Acura', se clasificarían bajo la nueva categoría model_v2 = 'RDX'. Esta simplificación tiene como objetivo mejorar la capacidad de generalización del modelo, reduciendo el número de categorías. No obstante, el número total de valores únicos para los modelos seguirá siendo elevado (alrededor de 700). Por esta razón, se propone extraer algunas características adicionales de cada modelo de vehículo. Para simplificar, en nuestro caso, se asignará un tipo de vehículo a cada modelo, como se detallará a continuación, y dicho tipo podrá tomar solo unos pocos valores: camioneta, compacto, deportivo, entre otros.
#
# Se podría plantear la inclusión de otras variables derivadas de la variable model, como indicadores que indiquen si las cadenas de texto 'sport', 'luxury', 'technology' u otras aparecen como substrings dentro de model. Sin embargo, por simplicidad, se ha decidido prescindir de estas variables.

# %% [markdown]
# At first glance, it is evident that the model names contain excessive detail, which may hinder the machine learning model's ability to generalize effectively. Therefore, it is proposed to reduce the set of possible values for the model variable for each brand to a list created based on expert criteria, ensuring that all models receive a new classification. For instance, two models such as 'Acura RDX Technology Package' and 'Acura RDX Technology & AcuraWatch Plus Package', both with make='Acura', would be classified under the new category model_v2 = 'RDX'. This simplification is intended to improve the model's generalization by reducing the number of categories. However, the total number of unique model values will still be high (around 700). For this reason, it is proposed to extract additional features for each vehicle model. For simplicity, in our case, a vehicle type will be assigned to each model, as detailed below, and this type will only take a few possible values: SUV, compact, sport-car, among others.
#
# The inclusion of additional variables derived from the model variable could be considered, such as indicators that specify whether the strings 'sport', 'luxury', 'technology', or others appear as substrings within model. However, for simplicity, it has been decided to omit these variables.

# %%
# Open the file containing the data
with open('model_vehicle_type.txt', 'r') as file:
    content = file.read()
models_dictionary = ast.literal_eval(content)
models_dictionary
# Out:
# {'acura': {'MDX': 'SUV',
#   'TSX': 'Compact',
#   'RDX': 'SUV',
#   'TLX': 'Mid-size',
#   'TL': 'Mid-size',
#   'ILX': 'Compact',
#   'ZDX': 'SUV',
#   'RLX': 'Large',
#   'RL': 'Large',
#   'NSX': 'Sport-car',
#   'RSX': 'Compact',
#   'INTEGRA': 'Compact',
#   'CL': 'Mid-size',
#   'LEGEND': 'Large'},
#  'audi': {'A2': 'Subcompact',
#   'A3': 'Compact',
#   'A4': 'Mid-size',
#   'A5': 'Mid-size',
#   'A6': 'Large',
#   'A7': 'Large',
#   'A8': 'Large',
#   'Q3': 'SUV',
#   'Q4': 'SUV',
#   'Q5': 'SUV',
#   'Q6': 'SUV',
#   'Q7': 'SUV',
#   'Q8': 'SUV',
#   'RS': 'Sport-car',
#   'TT': 'Sport-car',
#   'S3': 'Compact',
#   'S4': 'Mid-size',
#   'S5': 'Mid-size',
#   'S6': 'Large',
#   'S7': 'Large',
#   'S8': 'Large',
#   'R8': 'Sport-car',
#   'ALLROAD': 'Mid-size',
#   'E-TRON': 'SUV'},
#  'bmw': {'GRAN COUPE': 'Mid-size',
#   'ALPINA': 'Mid-size',
#   'ISETTA': 'Subcompact',
#   'ACTIVEHYBRID': 'Mid-size',
#   'X1': 'SUV',
#   'X2': 'SUV',
#   'X3': 'SUV',
#   'X4': 'SUV',
#   'X5': 'SUV',
#   'X6': 'SUV',
#   'X7': 'SUV',
#   'XM': 'SUV',
#   'Z3': 'Sport-car',
#   'Z4': 'Sport-car',
#   'Z8': 'Sport-car',
#   'M2': 'Sport-car',
#   'M3': 'Sport-car',
#   'M4': 'Sport-car',
#   'M5': 'Sport-car',
#   'M6': 'Sport-car',
#   'M8': 'Sport-car',
#   'M440': 'Compact',
#   'M235': 'Compact',
#   'M240': 'Compact',
#   'M760': 'Large',
#   'I3': 'Compact',
#   'I4': 'Compact',
#   'I5': 'Mid-size',
#   'I7': 'Large',
#   'I8': 'Sport-car',
#   'IX': 'SUV',
#   '128': 'Compact',
#   '135': 'Compact',
#   '228': 'Compact',
#   '230': 'Compact',
#   '318': 'Compact',
#   '320': 'Compact',
#   '323': 'Compact',
#   '328': 'Compact',
#   '325': 'Compact',
#   '330': 'Compact',
#   '335': 'Compact',
#   '340': 'Compact',
#   '428': 'Mid-size',
#   '430': 'Mid-size',
#   '435': 'Mid-size',
#   '440': 'Mid-size',
#   '445': 'Mid-size',
#   '525': 'Mid-size',
#   '528': 'Mid-size',
#   '530': 'Mid-size',
#   '535': 'Mid-size',
#   '540': 'Mid-size',
#   '545': 'Mid-size',
#   '550': 'Mid-size',
#   '633': 'Mid-size',
#   '635': 'Mid-size',
#   '640': 'Mid-size',
#   '645': 'Mid-size',
#   '650': 'Mid-size',
#   '700': 'Large',
#   '740': 'Large',
#   '745': 'Large',
#   '750': 'Large',
#   '760': 'Large',
#   '840': 'Large',
#   'M': 'Sport-car'},
#  'buick': {'ENCORE': 'SUV',
#   'CASCADA': 'Sport-car',
#   'VERANO': 'Compact',
#   'LACROSSE': 'Large',
#   'REGAL': 'Mid-size',
#   'ENCLAVE': 'SUV',
#   'ENVISION': 'SUV',
#   'LUCERNE': 'Large',
#   'ENVISTA': 'Compact',
#   'RIVIERA': 'Sport-car',
#   'ROADMASTER': 'Large',
#   'ELECTRA': 'Large',
#   'SUPER': 'Large',
#   'CENTURY': 'Mid-size',
#   'SKYLARK': 'Compact',
#   'LESABRE': 'Large',
#   'RENDEZVOUS': 'SUV',
#   'TERRAZA': 'Van',
#   'PARK AVENUE': 'Large',
#   'REATTA': 'Sport-car',
#   'WILDCAT': 'Sport-car',
#   'SPECIAL': 'Mid-size',
#   'RAINIER': 'SUV',
#   'MODEL 27': 'Large',
#   'SERIES 50 MODEL 56': 'Large',
#   'GRANSPORT': 'Sport-car'},
#  'cadillac': {'CT4': 'Compact',
#   'CT5': 'Mid-size',
#   'CT6': 'Large',
#   'CTS': 'Mid-size',
#   'XT4': 'SUV',
#   'XT5': 'SUV',
#   'XT6': 'SUV',
#   'XTS': 'Large',
#   'ESCALADE': 'SUV',
#   'ELDORADO': 'Large',
#   'DTS': 'Large',
#   'SRX': 'SUV',
#   'SERIES 62': 'Large',
#   'SERIES 61': 'Large',
#   'SERIES 60': 'Large',
#   'XLR': 'Sport-car',
#   'STS': 'Large',
#   'ATS': 'Compact',
#   'ALLANTE': 'Sport-car',
#   'DEVILLE': 'Large',
#   'SEVILLE': 'Large',
#   'LYRIQ': 'SUV',
#   'FLEETWOOD': 'Large',
#   'ELR': 'Compact',
#   'CATERA': 'Mid-size',
#   'OPTIQ': 'Compact',
#   'BROUGHAM': 'Large'},
#  'chevrolet': {'MALIBU': 'Mid-size',
#   'CORVETTE': 'Sport-car',
#   'BOLT': 'Compact',
#   'MONTE CARLO': 'Sport-car',
#   'SILVERADO': 'Truck',
#   'CAPRICE': 'Large',
#   'CAMARO': 'Sport-car',
#   'IMPALA': 'Large',
#   'SUBURBAN': 'SUV',
#   'EQUINOX': 'SUV',
#   'CAPTIVA': 'SUV',
#   'SPARK': 'Subcompact',
#   'COBALT': 'Compact',
#   'TRAVERSE': 'SUV',
#   'COLORADO': 'Truck',
#   'CRUZE': 'Compact',
#   'AVALANCHE': 'Truck',
#   'EXPRESS': 'Van',
#   'BLAZER': 'SUV',
#   'SONIC': 'Subcompact',
#   'TAHOE': 'SUV',
#   'CHEVELLE': 'Mid-size',
#   'TRAILBLAZER': 'SUV',
#   'NOMAD': 'Sport-car',
#   'TRAX': 'SUV',
#   'AVEO': 'Subcompact',
#   'MASTER': 'Van',
#   'FLEETLINE': 'Large',
#   '150': 'Truck',
#   '1500': 'Truck',
#   '210': 'Mid-size',
#   '2500': 'Truck',
#   '3100': 'Truck',
#   '3500': 'Truck',
#   'APACHE': 'Truck',
#   'ASTRO': 'Van',
#   'BEL': 'Large',
#   'LUMINA': 'Mid-size',
#   'LUV': 'Truck',
#   'NOVA': 'Compact',
#   'PICKUP': 'Truck',
#   'PRIZM': 'Compact',
#   'SPORTVAN': 'Van',
#   'STYLELINE': 'Large',
#   'TRACKER': 'SUV',
#   'UPLANDER': 'Van',
#   'VAN': 'Van',
#   'VENTURE': 'Van',
#   'VOLT': 'Compact',
#   'C10/K10': 'Truck',
#   'C20/K20': 'Truck',
#   'C30/K30': 'Truck',
#   'CAVALIER': 'Compact',
#   'CHEVY': 'Compact',
#   'CORVAIR': 'Compact',
#   'EL CAMINO': 'Sport-car',
#   'FLEETMASTER': 'Large',
#   'HHR': 'Compact',
#   'S-10': 'Truck',
#   'SS': 'Sport-car',
#   'SSR': 'Sport-car'},
#  'chrysler': {'CIRRUS': 'Mid-size',
#   'CONCORDE': 'Large',
#   'CROSSFIRE': 'Sport-car',
#   'IMPERIAL': 'Large',
#   'LEBARON': 'Mid-size',
#   'NEWPORT': 'Large',
#   'PACIFICA': 'SUV',
#   'PROWLER': 'Sport-car',
#   'SEBRING': 'Mid-size',
#   'TOWN': 'Van',
#   'VOYAGER': 'Van',
#   '300': 'Large',
#   '200': 'Mid-size',
#   'PT CRUISER': 'Compact',
#   'LHS': 'Large',
#   'TC BY MASERATI': 'Sport-car',
#   'NEW YORKER': 'Large',
#   'ASPEN': 'SUV'},
#  'dodge': {'AVENGER': 'Mid-size',
#   'CALIBER': 'Compact',
#   'CARAVAN': 'Van',
#   'CHALLENGER': 'Sport-car',
#   'CHARGER': 'Large',
#   'CORONET': 'Large',
#   'CUSTOM': 'Large',
#   'DAKOTA': 'Truck',
#   'DART': 'Compact',
#   'DAYTONA': 'Sport-car',
#   'DURANGO': 'SUV',
#   'DYNASTY': 'Mid-size',
#   'HORNET': 'Compact',
#   'INTREPID': 'Large',
#   'MAGNUM': 'Mid-size',
#   'MONACO': 'Large',
#   'NEON': 'Compact',
#   'NITRO': 'SUV',
#   'POLARA': 'Large',
#   'RAMCHARGER': 'SUV',
#   'ROYAL': 'Large',
#   'SPRINTER': 'Van',
#   'STEALTH': 'Sport-car',
#   'STRATUS': 'Mid-size',
#   'SUPER': 'Large',
#   'VIPER': 'Sport-car',
#   'RAM 1500': 'Truck',
#   'RAM 2500': 'Truck',
#   'RAM 3500': 'Truck',
#   'JOURNEY': 'SUV',
#   'RAM VAN': 'Van',
#   'RAM WAGON': 'Van',
#   '3/4': 'Truck',
#   '600': 'Mid-size',
#   'ASPEN': 'SUV',
#   'D150': 'Truck',
#   'D250': 'Truck',
#   'W250': 'Truck'},
#  'ford': {'BRONCO': 'SUV',
#   'CLUB': 'Van',
#   'CONTOUR': 'Mid-size',
#   'CROWN': 'Large',
#   'CUSTOM': 'Large',
#   'E-TRANSIT': 'Van',
#   'ECOSPORT': 'SUV',
#   'EDGE': 'SUV',
#   'ESCAPE': 'SUV',
#   'ESCORT': 'Compact',
#   'EXCURSION': 'SUV',
#   'EXPEDITION': 'SUV',
#   'EXPLORER': 'SUV',
#   'FAIRLANE': 'Mid-size',
#   'FALCON': 'Compact',
#   'FIESTA': 'Subcompact',
#   'FLEX': 'SUV',
#   'FOCUS': 'Compact',
#   'FREESTAR': 'Van',
#   'FREESTYLE': 'SUV',
#   'FUSION': 'Mid-size',
#   'GALAXIE': 'Large',
#   'MAVERICK': 'Truck',
#   'MUSTANG': 'Sport-car',
#   'PARKLANE': 'Large',
#   'PICKUP': 'Truck',
#   'PINTO': 'Subcompact',
#   'RANCH': 'Truck',
#   'RANCHERO': 'Truck',
#   'RANGER': 'Truck',
#   'SEDAN': 'Mid-size',
#   'SHELBY': 'Sport-car',
#   'TAURUS': 'Large',
#   'THUNDERBIRD': 'Large',
#   'TORINO': 'Mid-size',
#   'TRANSIT': 'Van',
#   'UTILITY': 'SUV',
#   'VICTORIA': 'Large',
#   'WINDSTAR': 'Van',
#   'E100': 'Van',
#   'E150': 'Van',
#   'E250': 'Van',
#   'E350': 'Van',
#   'F-150': 'Truck',
#   'F-250': 'Truck',
#   'F-350': 'Truck',
#   'F-450': 'Truck',
#   'F100': 'Truck',
#   'FIVE HUNDRED': 'Large',
#   'C-MAX': 'Compact',
#   'COUPE': 'Mid-size',
#   'DELUXE': 'Mid-size',
#   'MODEL A': 'Mid-size',
#   'MODEL T': 'Mid-size',
#   'MODEL 78': 'Mid-size'},
#  'gmc': {'CABALLERO': 'Truck',
#   'CANYON': 'Truck',
#   'ENVOY': 'SUV',
#   'HUMMER': 'SUV',
#   'JIMMY': 'SUV',
#   'PANEL': 'Van',
#   'PICKUP': 'Truck',
#   'RALLY': 'Van',
#   'SAFARI': 'Van',
#   'SAVANA 1500': 'Van',
#   'SAVANA 2500': 'Van',
#   'SAVANA 3500': 'Van',
#   'SIERRA 1500': 'Truck',
#   'SIERRA 2500': 'Truck',
#   'SIERRA 3500': 'Truck',
#   'SIERRA': 'Truck',
#   '1500': 'Truck',
#   'SONOMA': 'Truck',
#   'SPRINT': 'Truck',
#   'SUBURBAN': 'SUV',
#   'TERRAIN': 'SUV',
#   'YUKON': 'SUV',
#   'ACADIA': 'SUV'},
#  'honda': {'ACCORD': 'Mid-size',
#   'CIVIC': 'Compact',
#   'CLARITY': 'Mid-size',
#   'CROSSTOUR': 'Mid-size',
#   'ELEMENT': 'SUV',
#   'INSIGHT': 'Compact',
#   'ODYSSEY': 'Van',
#   'PASSPORT': 'SUV',
#   'PILOT': 'SUV',
#   'PRELUDE': 'Sport-car',
#   'PROLOGUE': 'SUV',
#   'RIDGELINE': 'Truck',
#   'CR-V': 'SUV',
#   'CR-Z': 'Compact',
#   'CRX': 'Compact',
#   'FIT': 'Subcompact',
#   'HR-V': 'SUV',
#   'S2000': 'Sport-car',
#   'DEL SOL': 'Sport-car'},
#  'hyundai': {'ACCENT': 'Subcompact',
#   'AZERA': 'Large',
#   'ELANTRA': 'Compact',
#   'ENTOURAGE': 'Van',
#   'EQUUS': 'Large',
#   'GENESIS': 'Large',
#   'IONIQ': 'Compact',
#   'KONA': 'SUV',
#   'NEXO': 'SUV',
#   'PALISADE': 'SUV',
#   'SONATA': 'Mid-size',
#   'TIBURON': 'Sport-car',
#   'TUCSON': 'SUV',
#   'VELOSTER': 'Compact',
#   'VENUE': 'Subcompact',
#   'VERACRUZ': 'SUV',
#   'XG350': 'Large',
#   'SANTA FE': 'SUV',
#   'SANTA CRUZ': 'Truck'},
#  'infiniti': {'EX35': 'SUV',
#   'EX37': 'SUV',
#   'FX35': 'SUV',
#   'FX37': 'SUV',
#   'FX45': 'SUV',
#   'FX50': 'SUV',
#   'G20': 'Compact',
#   'G25': 'Mid-size',
#   'G25X': 'Mid-size',
#   'G35': 'Mid-size',
#   'G35X': 'Mid-size',
#   'G37': 'Mid-size',
#   'G37X': 'Mid-size',
#   'I30': 'Mid-size',
#   'I35': 'Mid-size',
#   'J30': 'Mid-size',
#   'JX35': 'SUV',
#   'M30': 'Mid-size',
#   'M35': 'Mid-size',
#   'M35H': 'Mid-size',
#   'M35X': 'Mid-size',
#   'M37': 'Mid-size',
#   'M37X': 'Mid-size',
#   'M45': 'Large',
#   'M45X': 'Large',
#   'M56': 'Large',
#   'M56X': 'Large',
#   'Q40': 'Mid-size',
#   'Q45': 'Large',
#   'Q50': 'Mid-size',
#   'Q60': 'Sport-car',
#   'Q70': 'Large',
#   'Q70H': 'Large',
#   'Q70L': 'Large',
#   'QX30': 'SUV',
#   'QX4': 'SUV',
#   'QX50': 'SUV',
#   'QX55': 'SUV',
#   'QX56': 'SUV',
#   'QX60': 'SUV',
#   'QX70': 'SUV',
#   'QX80': 'SUV'},
#  'jeep': {'GRAND CHEROKEE': 'SUV',
#   'CHEROKEE': 'SUV',
#   'COMANCHE': 'Truck',
#   'COMMANDER': 'SUV',
#   'NEW COMPASS': 'SUV',
#   'GLADIATOR': 'Truck',
#   'COMPASS': 'SUV',
#   'CJ-7': 'SUV',
#   'CJ-5': 'SUV',
#   'CJ': 'SUV',
#   'JEEPSTER': 'SUV',
#   'LIBERTY': 'SUV',
#   'PATRIOT': 'SUV',
#   'RENEGADE': 'SUV',
#   'SCRAMBLER': 'Truck',
#   'GRAND WAGONEER': 'SUV',
#   'WAGONEER': 'SUV',
#   'WRANGLER': 'SUV'},
#  'kia': {'AMANTI': 'Large',
#   'BORREGO': 'SUV',
#   'CADENZA': 'Large',
#   'CARNIVAL': 'Van',
#   'NIRO': 'Compact',
#   'OPTIMA': 'Mid-size',
#   'RONDO': 'Compact',
#   'SEDONA': 'Van',
#   'SELTOS': 'SUV',
#   'SORENTO': 'SUV',
#   'SOUL': 'Subcompact',
#   'SPORTAGE': 'SUV',
#   'STINGER': 'Sport-car',
#   'TELLURIDE': 'SUV',
#   'SPECTRA': 'Compact',
#   'SPECTRA5': 'Compact',
#   'RIO': 'Subcompact',
#   'RIO5': 'Subcompact',
#   'EV6': 'Mid-size',
#   'EV9': 'SUV',
#   'FORTE': 'Compact',
#   'K4': 'Compact',
#   'K5': 'Mid-size',
#   'K900': 'Large'},
#  'land_rover': {'DEFENDER': 'SUV',
#   'DISCOVERY': 'SUV',
#   'LR2': 'SUV',
#   'LR3': 'SUV',
#   'LR4': 'SUV',
#   'RANGE ROVER EVOQUE': 'SUV',
#   'RANGE ROVER VELAR': 'SUV',
#   'RANGE ROVER': 'SUV',
#   'SERIES III': 'SUV',
#   'SERIES II': 'SUV'},
#  'lexus': {'CT': 'Compact',
#   'ES': 'Mid-size',
#   'GS': 'Mid-size',
#   'GX': 'SUV',
#   'HS': 'Mid-size',
#   'IS': 'Compact',
#   'IS-F': 'Sport-car',
#   'LC': 'Sport-car',
#   'LS': 'Large',
#   'LX': 'SUV',
#   'NX': 'SUV',
#   'RC': 'Sport-car',
#   'RX': 'SUV',
#   'RZ': 'SUV',
#   'SC': 'Sport-car',
#   'TX': 'Large',
#   'UX': 'Compact'},
#  'lincoln': {'AVIATOR': 'SUV',
#   'BLACKWOOD': 'Truck',
#   'CAPRI': 'Mid-size',
#   'CONTINENTAL': 'Large',
#   'CORSAIR': 'SUV',
#   'COSMOPOLITAN': 'Large',
#   'LS': 'Mid-size',
#   'MKC': 'SUV',
#   'MKS': 'Mid-size',
#   'MKT': 'SUV',
#   'MKX': 'SUV',
#   'MKZ': 'Mid-size',
#   'MARK': 'Large',
#   'NAUTILUS': 'SUV',
#   'NAVIGATOR': 'SUV',
#   'PREMIERE': 'Large',
#   'TOWN CAR': 'Large',
#   'ZEPHYR': 'Mid-size'},
#  'mazda': {'626': 'Mid-size',
#   '929': 'Large',
#   'B2300': 'Truck',
#   'B2500': 'Truck',
#   'B3000': 'Truck',
#   'B4000': 'Truck',
#   'CX-3': 'SUV',
#   'CX-30': 'SUV',
#   'CX-5': 'SUV',
#   'CX-50': 'SUV',
#   'CX-7': 'SUV',
#   'CX-70': 'SUV',
#   'CX-9': 'SUV',
#   'CX-90': 'SUV',
#   'MPV': 'Van',
#   'MX-30': 'Sport-car',
#   'MX-5': 'Sport-car',
#   'MAZDA2': 'Subcompact',
#   'MAZDA3': 'Compact',
#   'MAZDA5': 'Van',
#   'MAZDA6': 'Mid-size',
#   'MAZDASPEED': 'Sport-car',
#   'MAZDASPEED3': 'Sport-car',
#   'MAZDASPEED6': 'Sport-car',
#   'PROTEGE': 'Compact',
#   'PROTEGE5': 'Compact',
#   'RX-3': 'Sport-car',
#   'RX-7': 'Sport-car',
#   'RX-8': 'Sport-car',
#   'TRIBUTE': 'SUV'},
#  'mercedes_benz': {'190SL': 'Sport-car',
#   '190': 'Compact',
#   '220D': 'Mid-size',
#   '220S': 'Mid-size',
#   '220SE': 'Mid-size',
#   '220': 'Mid-size',
#   '240D': 'Mid-size',
#   '250': 'Mid-size',
#   '280CE': 'Mid-size',
#   '280SE': 'Mid-size',
#   '280SL': 'Sport-car',
#   '300CD': 'Mid-size',
#   '300D': 'Mid-size',
#   '300GD': 'SUV',
#   '300TD': 'Mid-size',
#   '380': 'Mid-size',
#   '380SL': 'Sport-car',
#   '380SLC': 'Sport-car',
#   '450SL': 'Sport-car',
#   '500SEL': 'Large',
#   '500SL': 'Sport-car',
#   '560SL': 'Sport-car',
#   '560': 'Large',
#   'A-CLASS': 'Subcompact',
#   'AMG': 'Sport-car',
#   'B-CLASS': 'Compact',
#   'C-CLASS': 'Mid-size',
#   'CL-CLASS': 'Large',
#   'CLA': 'Compact',
#   'CLE': 'Mid-size',
#   'CLS': 'Mid-size',
#   'CLK-CLASS': 'Mid-size',
#   'E-CLASS': 'Large',
#   'EQB': 'SUV',
#   'EQE': 'Large',
#   'EQS': 'Large',
#   'R-CLASS': 'Van',
#   'S-CLASS': 'Large',
#   'SL': 'Sport-car',
#   'G-CLASS': 'SUV',
#   'GLA': 'SUV',
#   'GLB': 'SUV',
#   'GLC': 'SUV',
#   'GLE': 'SUV',
#   'GLK-Class': 'SUV',
#   'GLS': 'SUV',
#   'G': 'SUV',
#   'M-CLASS': 'SUV',
#   'MAYBACH': 'Large',
#   'METRIS': 'Van',
#   'SLC': 'Sport-car',
#   'SLK-Class': 'Sport-car',
#   'SLR': 'Sport-car',
#   'SLS': 'Sport-car',
#   'SPRINTER': 'Van'},
#  'mini': {'CLUBMAN': 'Compact',
#   'PACEMAN': 'SUV',
#   'CONVERTIBLE': 'Sport-car',
#   'COUNTRYMAN': 'SUV',
#   'COUPE': 'Sport-car',
#   'HARDTOP': 'Compact',
#   'ROADSTER': 'Sport-car',
#   'COOPER': 'Subcompact'},
#  'mitsubishi': {'3000GT': 'Sport-car',
#   'DIAMANTE': 'Large',
#   'ECLIPSE': 'Compact',
#   'ENDEAVOR': 'SUV',
#   'GALANT': 'Mid-size',
#   'LANCER': 'Compact',
#   'MIRAGE': 'Subcompact',
#   'MONTERO': 'SUV',
#   'OUTLANDER': 'SUV',
#   'RAIDER': 'Truck',
#   'I-MIEV': 'Subcompact'},
#  'nissan': {'240SX': 'Sport-car',
#   '300ZX': 'Sport-car',
#   '350Z': 'Sport-car',
#   '370Z': 'Sport-car',
#   'ARIYA': 'SUV',
#   'ALTIMA': 'Mid-size',
#   'ARMADA': 'SUV',
#   'CUBE': 'Subcompact',
#   'FRONTIER': 'Truck',
#   'GT-R': 'Sport-car',
#   'JUKE': 'SUV',
#   'KICKS': 'Subcompact',
#   'LEAF': 'Subcompact',
#   'MAXIMA': 'Large',
#   'MURANO': 'SUV',
#   'NV': 'Van',
#   'NV200': 'Van',
#   'NX': 'Compact',
#   'PATHFINDER': 'SUV',
#   'PICKUP': 'Truck',
#   'QUEST': 'Van',
#   'ROGUE': 'SUV',
#   'SENTRA': 'Compact',
#   'TITAN': 'Truck',
#   'VERSA': 'Subcompact',
#   'XTERRA': 'SUV',
#   'Z': 'Sport-car'},
#  'porsche': {'356': 'Sport-car',
#   '718': 'Sport-car',
#   '911': 'Sport-car',
#   '912': 'Sport-car',
#   '914': 'Sport-car',
#   '918': 'Sport-car',
#   '924': 'Sport-car',
#   '928': 'Sport-car',
#   '930': 'Sport-car',
#   '944': 'Sport-car',
#   '968': 'Sport-car',
#   'BOXSTER': 'Sport-car',
#   'CARRERA': 'Sport-car',
#   'CAYENNE': 'SUV',
#   'CAYMAN': 'Sport-car',
#   'MACAN': 'SUV',
#   'PANAMERA': 'Large',
#   'TAYCAN': 'Sport-car'},
#  'ram': {'1500': 'Truck',
#   '2500': 'Truck',
#   '3500': 'Truck',
#   'CARGO': 'Van',
#   'PROMASTER': 'Van'},
#  'subaru': {'ASCENT': 'SUV',
#   'B9': 'SUV',
#   'BRZ': 'Sport-car',
#   'BAJA': 'Truck',
#   'BRAT': 'Truck',
#   'CROSSTREK': 'SUV',
#   'FORESTER': 'SUV',
#   'IMPREZA': 'Compact',
#   'LEGACY': 'Mid-size',
#   'OUTBACK': 'SUV',
#   'SVX': 'Large',
#   'SOLTERRA': 'SUV',
#   'TRIBECA': 'SUV',
#   'WRX': 'Compact',
#   'XV': 'SUV'},
#  'tesla': {'CYBERTRUCK': 'Truck',
#   'MODEL S': 'Large',
#   'MODEL X': 'SUV',
#   'MODEL Y': 'SUV',
#   'MODEL 3': 'Compact',
#   'ROADSTER': 'Sport-car'},
#  'toyota': {'LAND CRUISER': 'SUV',
#   'PREVIA': 'Van',
#   '4RUNNER': 'SUV',
#   '86': 'Sport-car',
#   'AVALON': 'Large',
#   'C-HR': 'SUV',
#   'CAMRY': 'Mid-size',
#   'CELICA': 'Sport-car',
#   'COROLLA': 'Compact',
#   'CROWN': 'Large',
#   'ECHO': 'Subcompact',
#   'FJ': 'SUV',
#   'GR86': 'Sport-car',
#   'GR': 'Sport-car',
#   'HIGHLANDER': 'SUV',
#   'MR2': 'Sport-car',
#   'MATRIX': 'Compact',
#   'MIRAI': 'Mid-size',
#   'PICKUP': 'Truck',
#   'PRIUS': 'Compact',
#   'RAV4': 'SUV',
#   'SEQUOIA': 'SUV',
#   'SIENNA': 'Van',
#   'SUPRA': 'Sport-car',
#   'TACOMA': 'Truck',
#   'TERCEL': 'Subcompact',
#   'TUNDRA': 'Truck',
#   'VENZA': 'Mid-size',
#   'YARIS': 'Subcompact',
#   'BZ4X': 'SUV'},
#  'volkswagen': {'ARTEON': 'Mid-size',
#   'ATLAS': 'SUV',
#   'BEETLE': 'Compact',
#   'CABRIO': 'Compact',
#   'CORRADO': 'Sport-car',
#   'EOS': 'Compact',
#   'EUROVAN': 'Van',
#   'GLI': 'Compact',
#   'GTI': 'Compact',
#   'GOLF': 'Compact',
#   'ID': 'SUV',
#   'JETTA': 'Compact',
#   'KARMANN': 'Sport-car',
#   'MICROBUS': 'Van',
#   'PASSAT': 'Mid-size',
#   'PHAETON': 'Large',
#   'RABBIT': 'Compact',
#   'ROUTAN': 'Van',
#   'TAOS': 'SUV',
#   'THING': 'SUV',
#   'TIGUAN': 'SUV',
#   'TOUAREG': 'SUV',
#   'VANAGON': 'Van',
#   'E-GOLF': 'Compact',
#   'CC': 'Mid-size',
#   'TYPE 2': 'Van',
#   'TYPE 3': 'Compact',
#   'R32': 'Sport-car'},
#  'volvo': {'122': 'Mid-size',
#   '1800': 'Sport-car',
#   '240': 'Mid-size',
#   '850': 'Mid-size',
#   '940': 'Mid-size',
#   '960': 'Mid-size',
#   'C30': 'Compact',
#   'C40': 'Compact',
#   'C70': 'Mid-size',
#   'EX30': 'SUV',
#   'EX90': 'SUV',
#   'P1800': 'Sport-car',
#   'P1800E': 'Sport-car',
#   'S40': 'Compact',
#   'S60': 'Mid-size',
#   'S80': 'Large',
#   'S90': 'Large',
#   'V50': 'Compact',
#   'V60': 'Mid-size',
#   'V70': 'Mid-size',
#   'V90': 'Large',
#   'XC40': 'SUV',
#   'XC60': 'SUV',
#   'XC70': 'SUV',
#   'XC90': 'SUV'}}

# %%
def get_model(row):
    text=row['model'].upper()
    # For a given make, obtain all possible models from a closed list
    models =[model.upper() for model in list(models_dictionary[row['make']].keys())]
    for model in models:
        if model in text: # Check if the simplified model is contained in the
                          # original model and over-detailed text
            return model
        
    if row['make']=='buick': # Particular case
        return 'GRANSPORT'
    return None
      
df['model_v2'] = df.apply(get_model, axis=1)

# %%
# Check nulls in model_v2: There are not
df[(df['model_v2'].isnull())]['model'].unique()
# Out:
# array([], dtype=object)

# %%
original_num_models=len(df['model'].unique())
print(f"The original number of different car models was {original_num_models}")
num_models=len(df['model_v2'].unique())
print(f"The number of different car models considered now is {num_models}")
# Out:
# The original number of different car models was 9201
# The number of different car models considered now is 704

# %% [markdown]
# #### Vehicle type

# %% [markdown]
# Como se anticipó, el número de modelos diferentes ha sido reducido considerablemente, de aproximadamente 9,200 a unos 700. Sin embargo, este número aún puede resultar elevado para utilizarlo como una variable final en el modelo. Por ello, se propone como alternativa incorporar las características de cada modelo como variables, siempre que sean conocidas y no puedan ser personalizadas por el comprador. Ejemplos de estas características incluyen: tipo de vehículo, altura, anchura, longitud, tonelaje, tamaño del maletero, número de asientos, entre otros. No obstante, se excluyen atributos como el color o los llamados 'extras' (llantas, lunas tintadas, asientos con ventilación...).
#
# En nuestro caso, dada la escasez de datos, las limitaciones de tiempo y el alcance del proyecto, por simplicidad, hemos decidido derivar únicamente una variable del modelo de vehículo (y marca). Esta variable es el tipo de vehículo, que puede tomar los valores: subcompacto, compacto, mediano, grande, deportivo, SUV, furgoneta y camioneta.
#
# Para etiquetar los datos, es decir, asignar a cada modelo de cada marca el valor de la variable vehicle_type, se ha utilizado un modelo LLM, con el objetivo de agilizar una tarea rutinaria y fácilmente automatizable. El prompt utilizado se puede encontrar [aquí](https://github.com/jcllanu/residual-value/blob/main/car_classification_prompt.txt), y el modelo LLM empleado es el 4o mini de ChatGPT. De manera manual, se ha verificado que esta clasificación es coherente para aquellos modelos de vehículos con mayor porcentaje de población, con el fin de corregir alucinaciones en caso de que existieran.

# %% [markdown]
# As anticipated, the number of distinct models has been significantly reduced, from approximately 9,200 to around 700. However, this number may still be too high to use as a final variable in the model. Therefore, as an alternative, it is proposed to incorporate characteristics of each model as variables, provided they are known and cannot be customized by the buyer. Examples of such characteristics include: vehicle type, height, width, length, weight, trunk size, number of seats, among others. However, attributes such as color or so called 'extras' (tinted windows, refrigerated seats, alloy wheels, etc. ) are excluded.
#
# In our case, given the scarcity of data, time constraints, and the scope of the project, for simplicity, we have decided to derive only one variable from the vehicle model (and brand). This variable is vehicle type, which can take the following values: Subcompact, Compact, Mid-size, Large, Sport-car, SUV, Van, and Truck.
#
# To label the data, i.e., to assign the vehicle_type value to each model of each brand, an LLM model was used to speed up a routine and easily automatable task. The prompt used can be found [here](https://github.com/jcllanu/residual-value/blob/main/car_classification_prompt.txt), and the LLM model employed is ChatGPT's 4o mini. A manual verification was performed to ensure the classification is consistent for those vehicle models with the highest population percentage, in order to correct any potential hallucinations.

# %%
def get_vehicle_type(row):
    # Search in the labeled data the type of vehicle for each model and make
    return models_dictionary[row['make']][row['model_v2']] 
      
df['vehicle_type'] = df.apply(get_vehicle_type, axis=1)

# %%
# Save the information in an excel file to check for possible hallucinations
df.groupby(['make','model_v2','vehicle_type'], dropna=False).size().reset_index(name='Count').to_excel('vehicle_types.xlsx', index=False)

# %%
# Most populated models with their vehicle type assignation
df.groupby(['make','model_v2','vehicle_type'], dropna=False).size().reset_index(name='Count').sort_values(by='Count', ascending=False).head(50)
# Out:
#               make        model_v2 vehicle_type  Count
# 573     mitsubishi       OUTLANDER          SUV   2754
# 619            ram            1500        Truck   2600
# 219       chrysler        PACIFICA          SUV   2161
# 455     land_rover     RANGE ROVER          SUV   2115
# 561           mini         HARDTOP      Compact   1762
# 559           mini      COUNTRYMAN          SUV   1726
# 103          buick          ENCORE          SUV   1687
# 501          mazda            CX-5          SUV   1687
# 4            acura             MDX          SUV   1578
# 427           jeep        WRANGLER          SUV   1491
# 642          tesla         MODEL Y          SUV   1485
# 719          volvo            XC60          SUV   1483
# 639          tesla         MODEL 3      Compact   1482
# 720          volvo            XC90          SUV   1427
# 332            gmc     SIERRA 1500        Truck   1328
# 137       cadillac        ESCALADE          SUV   1316
# 633         subaru         OUTBACK          SUV   1117
# 538  mercedes_benz             AMG    Sport-car   1104
# 6            acura             RDX          SUV   1099
# 603        porsche             911    Sport-car   1097
# 418           jeep  GRAND CHEROKEE          SUV   1088
# 102          buick         ENCLAVE          SUV   1054
# 629         subaru       CROSSTREK          SUV   1043
# 616        porsche           MACAN          SUV   1030
# 614        porsche         CAYENNE          SUV   1024
# 542  mercedes_benz             CLA      Compact   1017
# 233          dodge         CHARGER        Large   1011
# 571     mitsubishi          MIRAGE   Subcompact    997
# 407       infiniti            QX60          SUV    984
# 24            audi              Q5          SUV    979
# 409       infiniti            QX80          SUV    972
# 630         subaru        FORESTER          SUV    937
# 674     volkswagen           ATLAS          SUV    929
# 471          lexus              RX          SUV    917
# 595         nissan           ROGUE          SUV    917
# 620            ram            2500        Truck    903
# 451     land_rover       DISCOVERY          SUV    895
# 343          honda            CR-V          SUV    892
# 340          honda          ACCORD     Mid-size    884
# 241          dodge         DURANGO          SUV    879
# 490        lincoln       NAVIGATOR          SUV    879
# 373        hyundai          TUCSON          SUV    839
# 480        lincoln         CORSAIR          SUV    839
# 339            gmc           YUKON          SUV    831
# 341          honda           CIVIC      Compact    825
# 370        hyundai        SANTA FE          SUV    823
# 193      chevrolet       SILVERADO        Truck    819
# 489        lincoln        NAUTILUS          SUV    808
# 232          dodge      CHALLENGER    Sport-car    803
# 149       cadillac             XT5          SUV    799

# %%
# We remove the original variable and substitute it for the processed one
df.drop(columns=['model'], inplace=True)
df.rename(columns={'model_v2': 'model'}, inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  mileage interior_color  \
# 0              2006     19  acura    76497          Biege
# 1              2021      4  acura    54931       Espresso
# 2              2017      8  acura   103720          Ebony
# 3              2024      1  acura    17309          Ebony
# 4              2017      8  acura    66552          Ebony
#
#           exterior_color fuel_type  \
# 0            Green Pearl  Gasoline
# 1   Majestic Black Pearl  Gasoline
# 2  Modern Steel Metallic  Gasoline
# 3   Platinum White Pearl  Gasoline
# 4    White Diamond Pearl  Gasoline
#
#                                               engine  price_USD  \
# 0  2.4L I-4 DOHC, i-VTEC variable valve control, ...    10995.0
# 1  2L I-4 gasoline direct injection, DOHC, VTEC v...    27985.0
# 2  3.5L V-6 gasoline direct injection, i-VTEC var...    17981.0
# 3  1.5L I-4 gasoline direct injection, DOHC, VTEC...    30049.0
# 4  3.5L V-6 i-VTEC variable valve control, premiu...    18950.0
#
#                                                  url  mpg_city  mpg_highway  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0         31.0
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0         27.0
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0         26.0
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0         36.0
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0         27.0
#
#    num_speeds transmission_type        drive_train stock_type    model  \
# 0         NaN         Automatic  Front-wheel Drive       Used      TSX
# 1        10.0         Automatic    All-wheel Drive       Used      RDX
# 2         NaN         Automatic    All-wheel Drive       Used      MDX
# 3         NaN         Automatic  Front-wheel Drive       Used  INTEGRA
# 4         NaN         Automatic    All-wheel Drive       Used      RDX
#
#   vehicle_type  engine_displacement  engine_cylinders
# 0      Compact                  2.4               4.0
# 1          SUV                  2.0               4.0
# 2          SUV                  3.5               6.0
# 3      Compact                  1.5               4.0
# 4          SUV                  3.5               6.0

# %% [markdown]
# #### Engine

# %% [markdown]
# De la variable engine, que está expresada en lenguaje natural, se pretende extraer tres variables que están disponibles en algunos de los casos: la cilindrada, el número de cilindros y la potencia en caballos de fuerza.

# %% [markdown]
# From the engine variable, which is expressed in natural language, the goal is to extract three variables that are provided in some cases: engine displacement, the number of cylinders, and horsepower.

# %%
df['engine'].unique()[:50]
# Out:
# array(['2.4L I-4 DOHC, i-VTEC variable valve control, premium unleaded,',
#        '2L I-4 gasoline direct injection, DOHC, VTEC variable valve cont',
#        '3.5L V-6 gasoline direct injection, i-VTEC variable valve contro',
#        '1.5L I-4 gasoline direct injection, DOHC, VTEC variable valve co',
#        '3.5L V-6 i-VTEC variable valve control, premium unleaded, engine',
#        '2.4L I4', '3.5L V6 24V GDI SOHC',
#        '3.5L V-6 gasoline direct injection, variable valve control, prem',
#        'Electric ZEV 490hp',
#        '3.0L PGM-FI 24V SOHC i-VTEC V6 -inc: Variable Cylinder Managemen',
#        'Gas', '2.0L I4 16V GDI DOHC Turbo', '3.5L V6 SOHC 24V',
#        'Electric', 'Turbo Gas',
#        '3L V-6 i-VTEC variable valve control, premium unleaded, engine w',
#        '2.4L I-4 gasoline direct injection, DOHC, i-VTEC variable valve',
#        '3.5L V6 24V MPFI SOHC',
#        '3.2L V-6 variable valve control, premium unleaded, engine with 2',
#        '3.5L V-6 variable valve control, premium unleaded, engine with 2',
#        '3.5L V-6 gasoline direct injection, i-VTEC VCM variable valve co',
#        '3.5L V-6 VTEC variable valve control, premium unleaded, engine w',
#        '2.4L I4 16V MPFI DOHC', '3.7L V6 24V MPFI SOHC',
#        '3.7L V-6 VTEC variable valve control, premium unleaded, engine w',
#        '2.4L I4 16V GDI DOHC', '2.0L I4 16V MPFI SOHC',
#        '2.3L I4 16V MPFI DOHC Turbo', '4 Cylinder Engine',
#        '201.0HP 2.4L 4 Cylinder Engine Gasoline Fuel',
#        '200.0HP 2.4L 4 Cylinder Engine Gasoline Fuel',
#        '2L I-4 i-VTEC variable valve control, premium unleaded, engine w',
#        'Intercooled Turbo Premium Unleaded I-4 1.5 L/91',
#        '3.5L V-6 port/direct injection, DOHC, VTC variable valve control',
#        '3.0L V6 24V MPFI SOHC Hybrid',
#        '279.0HP 3.5L V6 Cylinder Engine Gasoline Fuel',
#        '3.0L V6 24V GDI DOHC Turbo', '2.4L DOHC 16-Valve VTEC 4-Cylinder',
#        '286.0HP 3.5L V6 Cylinder Engine Gasoline Fuel',
#        '252.0HP 3.0L V6 Cylinder Engine Gasoline Fuel', '–',
#        '160.0HP 2.0L 4 Cylinder Engine Gasoline Fuel',
#        '290.0HP 3.5L V6 Cylinder Engine Gasoline Fuel', '2.4L DOHC 16V',
#        '2.0L I4',
#        '3L V-6 gasoline direct injection, DOHC, i-VTEC variable valve co',
#        '1.5L I-4 i-VTEC variable valve control, premium unleaded, engine',
#        '573.0HP 3.5L V6 Cylinder Engine Gas/Electric Hybrid',
#        '2.0L I4 16V MPFI DOHC', '3.5L V6'], dtype=object)

# %% [markdown]
# ##### Engine displacement

# %% [markdown]
# La cilindrada (o desplazamiento del motor) es el volumen total de los pistones dentro de los cilindros del motor, expresado en litros. En la variable engine, esta información puede estar expresada en diferentes unidades: litros, centímetros cúbicos, pulgadas cúbicas, entre otras. Para extraer la información, se aplicará una lógica específica basada en expresiones regulares.

# %% [markdown]
# Engine displacement is the total volume of the pistons within the engine cylinders, expressed in liters. In the engine variable, this information may be expressed in different units: liters, cubic centimeters, cubic inches, among others. A specific logic based on regular expressions will be applied to extract the information.

# %%
def get_left_hand_side_engine_displacement(text):
    # Get the number on the left hand-side of the text if any
    text=text.replace(',','')
    result=""
    already_found_dot=False
    for char in text[::-1]: #iterate in the reversed list
        if char.isdigit():
            result = char + result
        elif char == '.' and not already_found_dot:
            result = char + result
            already_found_dot=True   
        else:
            break  # Stop when we encounter a non-number, non-dot character, or a second dot
    return result

def get_engine_displacement(text):
    if text.replace('.', '', 1).isdigit() and text.count('.') < 2 and float(text)<10:
        return float(text)
    possible_splitters=['CC', 'cc', '-liter', 'liter', 'T','I','CI', 'ci','c.i.', '/','L ','L', 'l ', ' ']
    for splitter in possible_splitters:
        for i in range(text.count(splitter)):
            liters=get_left_hand_side_engine_displacement(text.split(splitter)[i].strip())
            if liters.replace('.', '', 1).isdigit() and liters.count('.')< 2:
                if splitter in ('CC', 'cc'):
                    return float(liters)/1000 # Convert CC into liters
                elif splitter in ('CI', 'ci', 'c.i.'):
                    return float(liters)/61.024 # Convert CI into liters
                elif splitter == ' ':
                    if '.' in liters and float(liters) < 10: #Check that the engine displacement makes business sense
                        return float(liters)
                elif splitter in ('T', 'I', '/'):
                    if float(liters) < 10: #Check that the engine displacement makes business sense
                        return float(liters)
                else:
                    if float(liters) < 10: #Check that the engine displacement makes business sense
                        return float(liters)
    return None
df['engine_displacement']=df['engine'].apply(get_engine_displacement)

# %%
# Check nulls in engine_displacement: All null values in engine_displacement are due to the fact that engine variable doesn't provide that information
df[df['engine_displacement'].isnull()]['engine'].unique()
# Out:
# array(['Electric ZEV 490hp', 'Gas', 'Electric', 'Turbo Gas',
#        '4 Cylinder Engine', '–', '4 Cylinder', 'Electric ZEV 358hp',
#        '6 Cylinder', 'Electric ZEV 499hp', 'Electric Motor', 'V6', 'I4',
#        'Engine: Dual Motor -inc: start/stop pushbutton', 'I-4 cyl',
#        'V6 Cylinder Engine', 'Electric ZEV', 'Supercharged Gas',
#        '355.0HP Electric Motor Electric Fuel System',
#        'Electric 402hp 490ft. lbs.',
#        'Dual Synchronous Electric Motors Engine', 'L Electric Motor',
#        'L 4-Cyl Engine', '0 Cylinders',
#        'Dual Asynchronous Electric Motors Engine',
#        'Dual AC Electric Motors', 'Plug-in Hybrid', 'Not Specified', 'V8',
#        'I6', 'Range-Extended Electric 168hp 184ft. lbs.',
#        'Straight 6 Cylinder Engine', 'Electric LEV3-SULEV30 170hp',
#        'ELECTRIC', '8 Cylinder Engine', 'AC Electric Motor',
#        'Turbo Diesel', '39.5L Electric Motor', '8 Cylinder',
#        'ELECTRIC MOTOR', 'Electric 536hp 549ft. lbs.',
#        ': 5th Generation Electric Synchronous Motor',
#        '5th Generation Electric Synchronous Motors',
#        'Electric Motor (181 hp @ 4800 rpm)', 'I-6 cyl',
#        'Electric SULEV II 170hp', 'V12', '401 Nailhead',
#        '425 W/ dual quads', '350 2BBL  V8', '300-4V V8', '300-2 V8',
#        '322 Nail Head V8', '401 Nailhead V8', 'V8 Other None', 'v8',
#        'Nail Head 401 V8', 'i8', '401 DUAL QUADS', 'V8 Other', '305V8',
#        '350', '455 -4', '3 Cylinder', '455 V8', '455 CU INCH', '401  V8',
#        'other', 'V8 7.7', 'Electric ZEV 300hp', '500 Cubic Inch',
#        'Electric Drive Unit',
#        '340.0HP Electric Motor Electric Fuel System', '331 V8',
#        '390 cu.in. V8', 'Range-Extended Electric 181hp 295ft. lbs.',
#        '8 SELECT', 'UNKNOWN', '429 V8', 'Electric drive unit', '429  V8',
#        'Engine None', '346 CU 140 hp V8', '390', 'Front Drive Unit',
#        '350 Crate Fuel Injection V8', '350 SBC other', '283 V8',
#        'Electric 200hp 266ft. lbs.',
#        'Integral drive unit with electric motor', '235 I6', 'Hybrid',
#        'CORVETTE LT-1', '327 V8', 'Voltec Electric Drive Unit', '396 V8',
#        'Corvette L98', 'GDI DOHC', 'Electric 140hp 327ft. lbs.',
#        '396 L35 V8',
#        'Engine, Vortec 5300 V8 SFI (300 HP [223.7 kW] @ 5200 rpm, 335 lb',
#        'Ramjet 350 V8', '350 V8',
#        'Range-Extended Electric 149hp 273ft. lbs.', 'VORTEC', '454 V8',
#        '235.5', '496', '396', '110 V6', '427 V8', '400 V8', '327',
#        '383 Stroker V8', '3 Cylinder Engine', '489V8',
#        'Turbo  4 Cylinder', 'V-6 cyl', '440 V8', '360 V8', '318 V8',
#        'V42.4L', '383 V8', '383 Magnum V8', '6-Cyl, HO Turbo Dsl',
#        '431 cu.in. V8', 'V10', '318 cu. in. V8', '270 Cu V8', 'Inline 4',
#        'V-8 cyl', '340  other', 'Select', '273 V8', '340 V8', '36',
#        '460  V8', '181HP', 'Flathead   V8', 'Fuel-Injected 302 V8',
#        'Flathead V8', 'Dual Electric Motor', '107kW Electric Motor',
#        'Electric 143hp 184ft. lbs.', 'Electric 123hp 181ft. lbs.', '302',
#        '390 V8', '305 V8', '428 Cobra Jet V8',
#        '91KWH USABLE EXT NCM BATT',
#        '266.0HP Electric Motor Electric Fuel System', 'Turbo Hybrid',
#        'I4 Hybrid', 'Electric 580hp 775ft. lbs.',
#        'Electric 452hp 775ft. lbs.', '312 V8',
#        'Electric 266hp 428ft. lbs.', '302 V8', '996', '289',
#        '201 4 Cylinder', 'V Other', '289 V8', '68KWH USABLE STD BATTERY',
#        '4 Cylinder Flat Head other', '350 ZZ2 360HP   other', '327  V8',
#        '99M', '292 cu.in. V8', '239 Flathead V8', 'Supercharged 350 V8',
#        'Engine (cm3):     Inline-4', 'PRFM/91KWH USABLE EXT BTTRY',
#        '170 cu in other', 'V8 Flexible Fuel', '390 V8 V8', 'V8 V8',
#        'Vortec 2200 L4 MFI, (120 HP [89.5kW] @ 5000 rpm, 140 lb-ft [189.',
#        'Electric 1000hp 1200ft. lbs.', 'V6 235 Cubic Inch', 'ATK 383',
#        'Electric 830hp 1045ft. lbs.', '3 Performance Electric Motors',
#        '350  V8', 'OHV', 'Electric ZEV 212hp', 'Electric ZEV 288hp',
#        'I4 DOHC 16V Turbocharged', 'Dual Electric Motors',
#        'Electric 212hp 236ft. lbs.', 'No data',
#        '134.0HP Electric Motor Electric Fuel System',
#        'Electric 118hp 218ft. lbs.', 'Electric 134hp 218ft. lbs.',
#        '150kW 201HP Electric',
#        '225.0HP Electric Motor Electric Fuel System', '185HP',
#        'Engine: 165kW + 74kW 320HP Dual Electric', 'Electric ZEV 320hp',
#        'Chevy 350 V8', 'Magnum', '304', '8 cylinder', '360V8', '392 Hemi',
#        '201HP Electric Motor', 'Electric 201hp 291ft. lbs.',
#        'Engine: 76.1kW 215HP Electric', 'Engine: 99.8kW 379HP Electric',
#        'Dual 77.4 kWh Electric Motors',
#        '201.0HP Electric Motor Electric Fuel System',
#        '109 hp AC Electric Motor', '201hp Electric Motor Engine',
#        'Electric 109hp 210ft. lbs.', 'V6 Supercharged',
#        'Supercharged LS3', 'DIESEL', '4 300TDI', 'SuperCharged V8',
#        'Turbodiesel', 'V8 460 Cubic Inches', '460 V8', '368 Y BLOCK',
#        '368 Y Block  V8', 'Electric ZEV 143hp', 'Rotary engine',
#        '143 HP E-SKYACTIV ELECTRIC MOTOR', 'Single Electric Motor',
#        'Engine: Dual Perm. Synchronous Electric Motors -inc: front async',
#        'Permanently Synchronous Electric Motors Engine',
#        '617.0HP Electric Motor Electric Fuel System',
#        '177.0HP Electric Motor Electric Fuel System',
#        'Electric 288hp 564ft. lbs.',
#        '649.0HP Electric Motor Electric Fuel System',
#        'Electric 649hp 700ft. lbs.', 'Electric 617hp 701ft. lbs.',
#        'diesel', 'Electric 288hp 384ft. lbs.',
#        '2015 Mercedes S550, Black with Tan Leather interior,73k V8 Auto,',
#        'Diesel', 'Electric 329hp 417ft. lbs.',
#        'Electric 181hp 199ft. lbs.',
#        '181.0HP Electric Motor Electric Fuel System', 'yes',
#        '4-Cyl, Supercharged', 'AC Synchronous Electric Motor',
#        '80kW AC Synchronous Motor', 'VG30DE',
#        '160kW AC Synchronous Motor',
#        '107.0HP Electric Motor Electric Fuel System', 'FLAT 6',
#        '482.0HP Electric Motor Electric Fuel System',
#        '321.0HP Electric Motor Electric Fuel System',
#        'Electric 562hp 479ft. lbs.', 'Electric 590hp 626ft. lbs.',
#        'Electric ZEV 429hp', 'Electric 402hp 254ft. lbs.',
#        'AC ELECTRIC MOTOR', '4 cyl', 'Electric 750hp 774ft. lbs.',
#        'Flat 6 Cylinder Engine',
#        '509.0HP Electric Motor Electric Fuel System', 'H6',
#        'Electric ZEV 382hp',
#        '429.0HP Electric Motor Electric Fuel System', '4 Cyl other',
#        '616.0HP Electric Motor Electric Fuel System', '4 Cylinder 240hp',
#        'Electric 522hp 472ft. lbs.', 'Electric ZEV 576hp',
#        'Electric 670hp 626ft. lbs.',
#        '375.0HP Electric Motor Electric Fuel System',
#        'AC Permanent Synchronous Motors', 'SMPI', 'LITER ENGINE',
#        'Engine: Front & Rear eAxle w/AC Synchronous Electric Motor',
#        'H-4 cyl', 'Front & Rear eAxle w/AC Synchronous Electric Motor',
#        '215.0HP Electric Motor Electric Fuel System',
#        'Electric 346hp 389ft. lbs.', '53 kWh Lithium-Ion Battery',
#        'Electric 593hp 525ft. lbs.', 'Electric 302hp 317ft. lbs.',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet',
#        'Electric Motor Electric Fuel System',
#        'Electric 283hp 317ft. lbs.',
#        '691.0HP Electric Motor Electric Fuel System',
#        'Electric 328hp 387ft. lbs.',
#        '518.0HP Electric Motor Electric Fuel System',
#        '362.0HP Electric Motor Electric Fuel System',
#        '425.0HP Electric Motor Electric Fuel System',
#        '670.0HP Electric Motor Electric Fuel System',
#        'Electric 463hp 713ft. lbs.', 'Dual AC ElectricMotors HP',
#        '455.0HP Electric Motor Electric Fuel System',
#        'Electric 834hp 740ft. lbs.', 'Electric 416hp 443ft. lbs.',
#        'Motor: AC Permanent Magnet',
#        '600.0HP Electric Motor Electric Fuel System',
#        '417.0HP Electric Motor Electric Fuel System',
#        '534.0HP Electric Motor Electric Fuel System',
#        '271.0HP Electric Motor Electric Fuel System',
#        'Electric 449hp 389ft. lbs.',
#        '845.0HP Electric Motor Electric Fuel System',
#        'DUAL MOTOR FR AC INDUCTION/RR AC PERMANENT MAGNET',
#        'Electric 417hp 485ft. lbs.', 'Electric 1020hp',
#        '382.0HP Electric Motor Electric Fuel System',
#        'Electric 762hp 730ft. lbs.', 'Electric 670hp',
#        'Motors: Front AC Permanent Magnet w/OPTWL2-inc: rear AC inductio',
#        '416.0HP Electric Motor Electric Fuel System',
#        '328.0HP Electric Motor Electric Fuel System',
#        'MOTOR AC PERMANENT MAGNET', 'Electric 518hp 487ft. lbs.', 'L',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet -inc: 325 mil',
#        '380.0HP Electric Motor Electric Fuel System',
#        'Front & Rear High Efficiency -inc: 100 kWh battery',
#        'Electric 329hp 406ft. lbs.',
#        'Motors: Front Permanent Magnet -inc: Three high performance moto',
#        'Motor AC Permanent Magnet -inc 272 mi estimated',
#        'Dual AC Electric Motors, High Performance Rear',
#        'Single Motor: Rear AC Permanent Magnet',
#        'Motors: Front Permanent Magnet w/OPTWL-inc: rear AC induction mo',
#        'Dual Motor: Front & Rear High Efficiency -inc: 75 kWh battery',
#        '0 Cyl', 'ZYTEK PERMANENT MAGNET MOTOR',
#        '85 kWh 3-phase 4-pole AC induction motor w/copper',
#        '288.0HP Electric Motor Electric Fuel System',
#        '1020.0HP Electric Motor Electric Fuel System',
#        'Motors: Front & Rear AC Permanent Magnet',
#        '557.0HP Electric Motor Electric Fuel System',
#        'Dual Motor: Fr Ac Induction/rr Ac Permanent Magnet',
#        'Electric 382hp 325ft. lbs.', 'Electric 201hp 258ft. lbs.',
#        'DUAL AC ELECTRIC MOTORS',
#        '248.0HP Electric Motor Electric Fuel System', '75 kWh Elect',
#        '315.0HP Electric Motor Electric Fuel System',
#        'Electric 480hp 471ft. lbs.', 'Electric 510hp 547ft. lbs.',
#        'Electric 450hp 471ft. lbs.',
#        '3-phase 4-pole AC induction motor w/copper rotor',
#        'Electric 532hp 713ft. lbs.', 'Electric 271hp 310ft. lbs.',
#        'Motor: AC Permanent Magnet -inc: 272 mi estimated range',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet -inc: 325+ mi',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet -inc: 318 mil',
#        'DUAL AC ELECTRIC PERFORMANCE MOTORS',
#        'Motors: Front Ac Permanent Magnet/rr Ac Induction',
#        '258.0HP Electric Motor Electric Fuel System',
#        'FRONT HIGH EFFICIENCY/REAR HIGH PERFORMANCE -INC',
#        'Triple AC Electric Motors', '3-PHASE/4-POLE ELECTRIC',
#        'MOTORS FRONT AC PERMANENT MAGNET W/OPTWL2-INC', '691.0hp',
#        '346 HP Electric', '100 kWh Elect',
#        'Dual Motor: Fr AC Induction/ Rr AC Permanent Magnet', '455.0hp',
#        '295.0HP Electric Motor Electric Fuel System',
#        'Electric 518hp 387ft. lbs.', 'Electric 258hp 317ft. lbs.',
#        'Tri-Motor: Fr Ac Perm Magnet/rr Dual Ac Induction',
#        'Electric 425hp 475ft. lbs.', 'Electric Motor, 425 HP',
#        'Front & Rear High Efficiency Engine',
#        'Motors: Front & Rear Ac Permanent Magnet',
#        '12-Cylinder Electric ZEV',
#        'Dual Motor: Fr Ac Induction/ Rr Ac Permanent Magnet',
#        'Electric 4-Cylinder',
#        '214.0HP Electric Motor Electric Fuel System', 'V6 Hybrid',
#        'Electric Motor -inc: X-MODE w/snow/dirt, deep snow/mud and grip',
#        '6 1FZ', 'AC Induction Motor', 'F4 Other', 'Electric 335hp',
#        '335.0HP Electric Motor Electric Fuel System', 'Flat 4', '98',
#        'Electric 115hp 199ft. lbs.',
#        '85KW 115HP Electric -inc: 24.2kWh lithium-ion battery',
#        'Air cooled other', 'H4', '4 cyl other', 'Transverse 4 other',
#        'Flat 4 other', '85KW 115HP Electric',
#        'Air Cooled Flat 4 Cylinder', 'Air Cooled 4 Cylinder other',
#        'Horizontally Opposed 4 Cylinder  other', '4 Cylinder 4 Cylinder',
#        'Flat 4 1600 other', 'WHOLESALE TO PUBLIC/SODL AS IS',
#        'Turbo Supercharged', 'Electric Dual Motor',
#        '402.0HP Electric Motor Electric Fuel System',
#        'Dual Electric Motors 78kWh', 'I4 Supercharged',
#        '5 Cylinder Engine',
#        '455 HP 4-CYL TURBOCHARGED ENGINE WITH E-BOOST',
#        '455 HP 4-CYL DIRECT INJECTED TURBOCHARGED ENGINE',
#        '455 HP 4-CYL TURBOCHARGED ENGINE', '4 Cylinder Hybrid engine',
#        'Engine: Direct-Injection Turbocharged', 'T5',
#        'Electric 402hp 486ft. lbs.'], dtype=object)

# %% [markdown]
# #### Engine cylinders

# %% [markdown]
# Para extraer la información de la variable engine, se aplicará una lógica específica basada en expresiones regulares. Los pistones pueden estar organizados de diferentes formas: en línea, en V, en W, en H, entre otras. Esta topología del motor podría ser utilizada como una variable adicional, pero, por simplicidad, se ha decidido prescindir de ella.

# %% [markdown]
# To extract the information from the engine variable, a specific logic based on regular expressions will be applied. The pistons can be arranged in different configurations: inline, V, W, H, among others. This engine topology could also be used as an additional variable, but for the sake of simplicity, it has been decided to exclude it.

# %%
def get_right_hand_side_cylinders(text):
    # Get the number on the right hand-side of the text if any
    result=""
    for char in text:
        if char.isdigit():
            result += char
        elif char =='.':
            return "" #This number has nothing to do with cylinders
        elif char =='V':
            return "" #This is the number of valves
        else:
            break  # Stop when we encounter a non-number, non-dot character, or a second dot
    return result

def get_left_hand_side_cylinders(text):
    # Get the number on the left hand-side of the text if any
    result=""
    for char in text[::-1]:
        if char.isdigit():
            result = char + result
        elif char =='.':
            return "" #This number has nothing to do with cylinders
        else:
            break  # Stop when we encounter a non-number, non-dot character, or a second dot
    return result

def get_engine_cylinders(text):
    possible_splitters=['Inline-','Flat-', 'Inline','Flat','Transverse','I-', 'V-', 
                        'W-', 'H-', 'L-', 'l-', 'IC', 'VR', 'I', 'H', 'V',  'T', 'L', 'F']
    for splitter in possible_splitters:
        for i in range(text.count(splitter)):
            #Evaluate if there is a number in the right hand side of the splitters associated to cylinders
            cylinders=get_right_hand_side_cylinders(text.split(splitter)[i+1].strip()) 

            if cylinders.isdigit() and 0<=int(cylinders)<=16 and \
                "VALVE" not in text.split(splitter)[i+1].upper()[:9]:
                # Check that the number of cylinders makes business sense
                # and it is not the number of valves
                return int(cylinders)
            
    possible_splitters=['-CYL', 'CYL']
    for splitter in possible_splitters:
        for i in range(text.upper().count(splitter)):
            #Evaluate if there is a number in the left hand side of the splitters associated to cylinders
            cylinders=get_left_hand_side_cylinders(text.upper().split(splitter)[i].strip())
            if cylinders.isdigit() and 0<=int(cylinders)<=16:
                # Check that the number of cylinders makes business sense
                return int(cylinders) 
    return None
df['engine_cylinders']=df['engine'].apply(get_engine_cylinders)

# %% [markdown]
# Hay muchos valores de la variable model que no tienen información sobre el número de cilindros

# %% [markdown]
# There are many values in the model variable that do not contain information about the number of cylinders.

# %%
# Count of cars by number of cylinders
df.groupby(['engine_cylinders'], dropna=False).size().reset_index(name='Count')
# Out:
#    engine_cylinders  Count
# 0               0.0     36
# 1               2.0      3
# 2               3.0   3397
# 3               4.0  62092
# 4               5.0    589
# 5               6.0  41684
# 6               8.0  17054
# 7              10.0    239
# 8              12.0     83
# 9               NaN  16008

# %%
print("There are",str(len(df[df['engine_cylinders'].isnull()]['engine'])), "cars in which the number of cylinders hasn't been obtained")

df[df['engine_cylinders'].isnull()]['engine'].unique()
# Out:
# There are 16008 cars in which the number of cylinders hasn't been obtained
# array(['Electric ZEV 490hp', 'Gas', 'Electric', 'Turbo Gas', '–',
#        '2.4L DOHC 16V', 'Electric ZEV 358hp', '2.0L 16V DOHC', '2.4L',
#        '3.5L', '3.7L', 'Electric ZEV 499hp', 'Electric Motor',
#        '2.0L 16-Valve DOHC VTEC Turbo Engine', '2.0 L', '2.0L DOHC',
#        'Engine: Dual Motor -inc: start/stop pushbutton', '3.5 L',
#        '3.7 Liter', '3.5', '3.5L 273.0hp', '3.5L 290.0hp', '3.7',
#        '3.0L TFSI', 'Electric ZEV', '2.0 Liter Turbo', '2.0L', '1.8L',
#        '3.0L', '0.0', '2.9L', 'Supercharged Gas', '0.0L', '5.2L', '2.5L',
#        '355.0HP Electric Motor Electric Fuel System',
#        'Electric 402hp 490ft. lbs.', '2.0L Turbocharged',
#        'Dual Synchronous Electric Motors Engine', 'L Electric Motor',
#        '3.0L Supercharged', 'Dual Asynchronous Electric Motors Engine',
#        '2.0L TFSI', 'Dual AC Electric Motors', '4.0L', 'Plug-in Hybrid',
#        'Not Specified', '2.0-liter TFSI four-cylinder engine',
#        '2.0L 252.0hp', '4.2L',
#        'Range-Extended Electric 168hp 184ft. lbs.', '3.2', '2.5I',
#        '3.0-liter dual overhead cam (DOHC), 24-valve inline turbocharged',
#        '0.65L', 'N54 3.0L', 'ELECTRIC',
#        '170.0HP 0.65L Electric Motor Electric Fuel System',
#        '3.0-liter dual overhead cam (DOHC), 24-valve inline 230-horsepow',
#        'AC Electric Motor', '4.4L', 'Turbo Diesel', '0.0L:0',
#        '39.5L Electric Motor', '0.7 I', 'ELECTRIC MOTOR',
#        'Electric 536hp 549ft. lbs.',
#        ': 5th Generation Electric Synchronous Motor',
#        '1800 CC Flat Four other',
#        '5th Generation Electric Synchronous Motors',
#        'Electric Motor (181 hp @ 4800 rpm)',
#        'Electric/Gas 0.65 L/39.5 Cu.in. Range Extender', '4.4',
#        '3.2 Liter', 'Electric SULEV II 170hp', '3.4L', '4.4L 443.0hp',
#        '0.65L Electric Motor', '2.5 Liter In-Line Six Cylinder', '247CC',
#        'Gas 1.2L/', '2.4', '401 Nailhead', '425 W/ dual quads',
#        'Engine, ECOTEC 1.3L Turbo (GM-estimated 155 hp [115 kW] @ 5,600',
#        '3.6L', 'ECOTEC 1.3L Turbo', '1.4L', '1.6L', 'v8', '2.0', '3.8L',
#        'Turbocharged 1.3/', 'i8', '401 DUAL QUADS', '350',
#        'ECOTEC 1.2L Turbo', '455 -4', '1.4', 'Turbocharged 1.2/',
#        '455 CU INCH', 'ECOTEC 1.4L Turbo', 'Ecotec 1.3L Turbo Engine',
#        'other', 'ECOTEC TURBO 1.4L VARIABLE VALVE TIMING DOHC', '3.6',
#        'Electric ZEV 300hp', '500 Cubic Inch', 'Electric Drive Unit',
#        '340.0HP Electric Motor Electric Fuel System',
#        'Gas/Electric 1.4L/85.3',
#        'Range-Extended Electric 181hp 295ft. lbs.', '8 SELECT', 'UNKNOWN',
#        '8', '4.5L', '6.2L', '4.1L', '5.4L', '3.6L 308.0hp',
#        'Electric drive unit', 'Engine None', '429ci',
#        'DURAMAX 3.0L TURBO DIESEL', '3.0', '390', 'Front Drive Unit',
#        '5.7 L other', '350 SBC other', 'LS 5.3  other',
#        'Electric 200hp 266ft. lbs.',
#        'Integral drive unit with electric motor', '2.2L', 'Hybrid',
#        '8 396CI', '4/Range-Extend', '5.3L', 'CORVETTE LT-1', '2.7L Turbo',
#        '1.5L DOHC', '1.4L DOHC', '5.7L', '5.3',
#        'ECOTEC 1.3L Turbo engine', 'Voltec Electric Drive Unit', '350cid',
#        '4.3L', '2.8L Duramax Turbodiesel',
#        'ENGINE, RANGE EXTENDER, 1.4L INTERNAL COMBUSTION ENGINE', '6.0L',
#        'Corvette L98', 'GDI DOHC', 'Electric 140hp 327ft. lbs.', '9.9',
#        'Range-Extended Electric 149hp 273ft. lbs.', '4.3', 'VORTEC',
#        '164ci', '235.5', 'Thriftmaster Straight 6 235ci', '496', '396',
#        '350ci vortec', '400ci', '327', '0/Range-Extend', '2.7', '6',
#        '3.6 L', '3.2L', '4.7L', '5.7', 'V42.4L', '318ci', '340ci',
#        '340  other', 'Select', '5.7L 345.0hp', '7.2L', '36', '440CI',
#        '5.9 Liter', '5.4L 235.0hp', '181HP', '2.5L iVCT', '5.0L',
#        'Dual Electric Motor', '107kW Electric Motor', '1.5L EcoBoost',
#        'Electric 143hp 184ft. lbs.', 'Electric 123hp 181ft. lbs.', '302',
#        '91KWH USABLE EXT NCM BATT',
#        '266.0HP Electric Motor Electric Fuel System', 'Turbo Hybrid',
#        'Electric 580hp 775ft. lbs.', '1.5L ECOBOOST W/START-STOP',
#        'Electric 452hp 775ft. lbs.', '1.5', '4.6L 225.0hp',
#        'Electric 266hp 428ft. lbs.', '2.3 L', '2.3L ECOBOOST ENGINE',
#        '2.0L ECOBOOST ENGINE', '996', '289', '5.0 L', 'V Other', '390ci',
#        '68KWH USABLE STD BATTERY', '3.9L', '2.3L ECOBOOST 315HP',
#        'Fuel-Injected 4.6L', 'TWIN-SCRL 2.0L ECOBOOST ENG',
#        '350 ZZ2 360HP   other', '99M', '3.5L POWERBOOST FULL HYBRID',
#        '2.3L', '2.0L 188.0hp', 'PRFM/91KWH USABLE EXT BTTRY',
#        '170 cu in other', '170 CI 2.8L  other', '1.6L GTDI EcoBoost',
#        'Turbocharged Gas 1.5L/92', 'Electric 1000hp 1200ft. lbs.',
#        'ATK 383', 'Electric 830hp 1045ft. lbs.',
#        '3 Performance Electric Motors', '2.7L Turbo High-Output engine',
#        '6.6 Liter', '2.5', 'OHV', 'Electric ZEV 212hp',
#        'Electric ZEV 288hp', '1.5L', '1.5 Liter', '2.4L 160hp',
#        '2.4L 166.0hp', 'Dual Electric Motors', '1.8', '3.5 Liter',
#        'Electric 212hp 236ft. lbs.', '1.5 L', 'No data',
#        '134.0HP Electric Motor Electric Fuel System',
#        'Electric 118hp 218ft. lbs.', '1.6 Liter', '3.8', '1.6',
#        'Electric 134hp 218ft. lbs.', '150kW 201HP Electric', '1.6L DOHC',
#        '225.0HP Electric Motor Electric Fuel System', '185HP', '3.3L',
#        'Engine: 165kW + 74kW 320HP Dual Electric', 'Electric ZEV 320hp',
#        '3.5L 306.0hp', '3.5L 280.0hp', '3.7L 328.0hp', '3.7L 325.0hp',
#        '3.7 L', '3.5L 265.0hp', '5.6 L', '3.5L 295.0hp', '6.4 L',
#        '304CI AMCJ', 'Magnum', '2.4 Liter', '3.6 Liter', '304',
#        '6.4L SRT HEMI 392', '392 Hemi', '3.3L DOHC',
#        '201HP Electric Motor', 'Electric 201hp 291ft. lbs.', '1.6 L',
#        'Engine: 76.1kW 215HP Electric', 'Engine: 99.8kW 379HP Electric',
#        'Dual 77.4 kWh Electric Motors',
#        '2.0L inline 4 double overhead camshaft 16V',
#        '1.6L Turbo DOHC CVVT',
#        '201.0HP Electric Motor Electric Fuel System', '3.3 L',
#        '109 hp AC Electric Motor', '201hp Electric Motor Engine',
#        'Electric 109hp 210ft. lbs.', '5.0L 375.0hp', '2.5L 300TDI',
#        'Supercharged LS3', 'DIESEL',
#        '2.0L Ingenium Turbocharged i4 (246HP)', '4 300TDI', '5 TD5',
#        '6.2L GM LS3', '2', '2.0L 247.0hp', '6.0L Diesel', 'Turbodiesel',
#        '5.0L DOHC', '4.6L', '4.6',
#        'HYBRID SYNERGY DRIVE (HSD)-INC 3.3L DOHC SMPI', '4.6L 380hp',
#        '3.0L 245.0hp', '1.8L Hybrid', '2.3L GTDI', '2.5L i-VCT',
#        '3.7L 305.0hp', '7.5', '2.0L GTDi', '368 Y BLOCK',
#        '2.0L GTDI FHEV', '2.0L TURBOCHARGED ENGINE', '3.7L 303.0hp',
#        '2.0L 240.0hp', '2.0L TURBOCHARGED ENGIINE', '3.0 L', '1.3L R2',
#        '1.3L Rotary MPFI OHV', '1.3L Rotary SPFI OHV Turbo',
#        '232.0HP 1.3L Rotary engine Gasoline Fuel',
#        'RENESIS 1.3L Rotary premium unleaded, engine with 238HP',
#        'Electric ZEV 143hp', '238.0HP 1.3L Rotary engine Gasoline Fuel',
#        'RENESIS 1.3L Rotary premium unleaded, engine with 212HP',
#        '1,146cc Naturally Aspirated Rotary', '1.1L Rotary 4 BBL',
#        '1.3L Rotary intercooled turbo, regular unleaded, engine with 255',
#        'Rotary engine', 'R2 1.3L Natural Aspiration', '2.5L 24V', '2.5 L',
#        '143 HP E-SKYACTIV ELECTRIC MOTOR', 'Single Electric Motor',
#        'Engine: Dual Perm. Synchronous Electric Motors -inc: front async',
#        'Electric Motor 0.0L', '4.5 Liter',
#        'Permanently Synchronous Electric Motors Engine',
#        '617.0HP Electric Motor Electric Fuel System',
#        '4.0 Liter Biturbo 416hp',
#        '177.0HP Electric Motor Electric Fuel System',
#        'Electric 288hp 564ft. lbs.',
#        '649.0HP Electric Motor Electric Fuel System',
#        'Electric 649hp 700ft. lbs.', 'Electric 617hp 701ft. lbs.',
#        'diesel', '3.0L 362.0hp', '2.0L 208.0hp',
#        'Electric 288hp 384ft. lbs.', '2.3', '1.9L', '5.5L', 'Diesel',
#        'Electric 329hp 417ft. lbs.', '2.0L 16V TwinPower Turbo',
#        '1.6 Liter Turbo', '1.5L 12V TwinPower Turbo',
#        'Electric 181hp 199ft. lbs.', '1.5L 12V Twin Power Turbo',
#        '181.0HP Electric Motor Electric Fuel System', 'yes',
#        '1.6L 172.0hp', '2.0L 16V TWIN POWER TURBO',
#        '2.0L 16V Twin Power Turbo', '1.6 LITER',
#        'Engine: 2.0L 16V Twin Power Turbo', '2.4L DOHC',
#        'AC Synchronous Electric Motor', '1.5L Direct-Injection Turbo',
#        '1.2', '1.2L', '1.2 L', '2.0L 148.0hp',
#        '80kW AC Synchronous Motor', '4.0L 261.0hp', '4.0 L', '4.0 Liter',
#        '2.0L 131.0hp', 'VG30DE', '3.5L 300.0hp', '5.6',
#        '160kW AC Synchronous Motor',
#        '107.0HP Electric Motor Electric Fuel System',
#        '1915cc Flat-Four w/ Dual Carbs', '2.7L', '1.6L Flat-Four',
#        '482.0HP Electric Motor Electric Fuel System',
#        '321.0HP Electric Motor Electric Fuel System',
#        'Electric 562hp 479ft. lbs.', 'Electric 590hp 626ft. lbs.',
#        'Electric ZEV 429hp', '3.0L 380.0hp', '4 1582CC',
#        'Electric 402hp 254ft. lbs.', 'AC ELECTRIC MOTOR',
#        '2.0L FLAT-FOUR', 'Electric 750hp 774ft. lbs.',
#        '4.0L Boxer 390 HP', '2.7 L Boxter',
#        '509.0HP Electric Motor Electric Fuel System', '2.7 Liter',
#        'Electric ZEV 382hp',
#        '429.0HP Electric Motor Electric Fuel System',
#        '1600 CC flat 4 Boxer-cylinder engine', '3.4L Flat Six',
#        '616.0HP Electric Motor Electric Fuel System',
#        'Electric 522hp 472ft. lbs.', 'Electric ZEV 576hp',
#        '4.0L Naturally Aspirated Boxer 6 Engine',
#        'Electric 670hp 626ft. lbs.',
#        '375.0HP Electric Motor Electric Fuel System',
#        'AC Permanent Synchronous Motors', '3.0 Liter',
#        '3.6L Twin Turbo Flat Six', '3.0L Twin-Turbo Flat-Six',
#        '3.6L Flat-Six', '3.3L Turbocharged Flat-Six', '6.7L', '5.7 L',
#        'SMPI', '5.7 Hemi', 'LITER ENGINE', '2.4L turbo',
#        '2.5L DOHC Intercooled High Boost Turbo -inc: Dual Active Valve C',
#        '2.5L DOHC Intercooled High Boost Turbocharged', '2.4 L',
#        'Engine: Front & Rear eAxle w/AC Synchronous Electric Motor',
#        '2.5L DOHC Intercooled Turbocharged',
#        '2.0L DOHC Intercooled Turbocharged -inc: Dual Active Valve Contr',
#        'Front & Rear eAxle w/AC Synchronous Electric Motor', '2.5L DOHC',
#        'Engine: 2.0L 16V DOHC', '2.5L 305.0hp',
#        '215.0HP Electric Motor Electric Fuel System',
#        'Engine: 2.0L DOHC DAVCS VVT -inc: Electronic Throttle Control (E',
#        '2.0L DOHC Intercooled Turbocharged', '4',
#        'Electric 346hp 389ft. lbs.', '53 kWh Lithium-Ion Battery',
#        'Electric 593hp 525ft. lbs.', 'Electric 302hp 317ft. lbs.',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet',
#        'Electric Motor Electric Fuel System',
#        'Electric 283hp 317ft. lbs.',
#        '691.0HP Electric Motor Electric Fuel System',
#        'Electric 328hp 387ft. lbs.',
#        '518.0HP Electric Motor Electric Fuel System',
#        '362.0HP Electric Motor Electric Fuel System',
#        '425.0HP Electric Motor Electric Fuel System',
#        '670.0HP Electric Motor Electric Fuel System',
#        'Electric 463hp 713ft. lbs.', 'Dual AC ElectricMotors HP',
#        '455.0HP Electric Motor Electric Fuel System',
#        'Electric 834hp 740ft. lbs.', 'Electric 416hp 443ft. lbs.',
#        'Motor: AC Permanent Magnet',
#        '600.0HP Electric Motor Electric Fuel System',
#        '417.0HP Electric Motor Electric Fuel System',
#        '534.0HP Electric Motor Electric Fuel System',
#        '271.0HP Electric Motor Electric Fuel System',
#        'Electric 449hp 389ft. lbs.',
#        '845.0HP Electric Motor Electric Fuel System',
#        'DUAL MOTOR FR AC INDUCTION/RR AC PERMANENT MAGNET',
#        'Electric 417hp 485ft. lbs.', 'Electric 1020hp',
#        '382.0HP Electric Motor Electric Fuel System',
#        'Electric 762hp 730ft. lbs.', 'Electric 670hp',
#        '416.0HP Electric Motor Electric Fuel System',
#        '328.0HP Electric Motor Electric Fuel System',
#        'MOTOR AC PERMANENT MAGNET', 'Electric 518hp 487ft. lbs.', 'L',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet -inc: 325 mil',
#        '380.0HP Electric Motor Electric Fuel System',
#        'Front & Rear High Efficiency -inc: 100 kWh battery',
#        'Electric 329hp 406ft. lbs.',
#        'Motors: Front Permanent Magnet -inc: Three high performance moto',
#        'Motor AC Permanent Magnet -inc 272 mi estimated',
#        'Dual AC Electric Motors, High Performance Rear',
#        'Single Motor: Rear AC Permanent Magnet',
#        'Motors: Front Permanent Magnet w/OPTWL-inc: rear AC induction mo',
#        'Dual Motor: Front & Rear High Efficiency -inc: 75 kWh battery',
#        'Acceleration 0-60 mph in 2.6 seconds',
#        'ZYTEK PERMANENT MAGNET MOTOR',
#        '85 kWh 3-phase 4-pole AC induction motor w/copper',
#        '288.0HP Electric Motor Electric Fuel System',
#        '1020.0HP Electric Motor Electric Fuel System',
#        'Motors: Front & Rear AC Permanent Magnet',
#        '557.0HP Electric Motor Electric Fuel System',
#        'Dual Motor: Fr Ac Induction/rr Ac Permanent Magnet',
#        'Electric 382hp 325ft. lbs.', 'Electric 201hp 258ft. lbs.',
#        'DUAL AC ELECTRIC MOTORS',
#        '248.0HP Electric Motor Electric Fuel System', '75 kWh Elect',
#        '315.0HP Electric Motor Electric Fuel System',
#        'Electric 480hp 471ft. lbs.', 'Electric 510hp 547ft. lbs.',
#        'Electric 450hp 471ft. lbs.',
#        '3-phase 4-pole AC induction motor w/copper rotor',
#        'Electric 532hp 713ft. lbs.', 'Electric 271hp 310ft. lbs.',
#        'Motor: AC Permanent Magnet -inc: 272 mi estimated range',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet -inc: 325+ mi',
#        'Dual Motor: Fr AC Induction/Rr AC Permanent Magnet -inc: 318 mil',
#        'DUAL AC ELECTRIC PERFORMANCE MOTORS',
#        'Motors: Front Ac Permanent Magnet/rr Ac Induction',
#        '258.0HP Electric Motor Electric Fuel System',
#        'FRONT HIGH EFFICIENCY/REAR HIGH PERFORMANCE -INC',
#        'Triple AC Electric Motors', '3-PHASE/4-POLE ELECTRIC', '691.0hp',
#        '346 HP Electric', '100 kWh Elect',
#        'Dual Motor: Fr AC Induction/ Rr AC Permanent Magnet', '455.0hp',
#        '295.0HP Electric Motor Electric Fuel System',
#        'Electric 518hp 387ft. lbs.', 'Electric 258hp 317ft. lbs.',
#        'Tri-Motor: Fr Ac Perm Magnet/rr Dual Ac Induction',
#        'Electric 425hp 475ft. lbs.', 'Electric Motor, 425 HP',
#        'Front & Rear High Efficiency Engine',
#        'Motors: Front & Rear Ac Permanent Magnet',
#        '0.0 I Electric Fuel System',
#        'Dual Motor: Fr Ac Induction/ Rr Ac Permanent Magnet',
#        '214.0HP Electric Motor Electric Fuel System',
#        'Electric Motor -inc: X-MODE w/snow/dirt, deep snow/mud and grip',
#        '6 1FZ', '4.7', '3.0L Twin Turbo 2JZ Inline Six',
#        'AC Induction Motor', '4.7 Liter', '1.8L TSI',
#        '2.0L TSI 200hp Engine', '1.4 L', '2.0L TSI', '1.4L TSI',
#        'Electric 335hp', '2.0L TSI DOHC',
#        '335.0HP Electric Motor Electric Fuel System',
#        '2.0L TDI Diesel Turbocharged', '1.8 TSI 170HP', '98',
#        '2.1L PORSCHE ENGINE other', 'Electric 115hp 199ft. lbs.',
#        '1600 CC other', '1500cc other', '1600 CC  other',
#        '85KW 115HP Electric -inc: 24.2kWh lithium-ion battery',
#        'Air cooled other', '1300cc', '1600CC', '1600cc other',
#        '2110 cc Air Cooled Boxer 4', '1976 cc other',
#        '85KW 115HP Electric', '2.0L TDI Diesel', '1600cc', '1600CC other',
#        '1600 CC Dual Port other other', '2.0L TSI 200 hp', '2.8',
#        'WHOLESALE TO PUBLIC/SODL AS IS', '1700cc',
#        'Engine: 2.0L TDI Diesel', 'Turbo Supercharged',
#        'Electric Dual Motor',
#        '402.0HP Electric Motor Electric Fuel System',
#        'Dual Electric Motors 78kWh', '0', '2.0L Electric Motor',
#        'Engine: 2.0L Direct-Injected Turbocharged', '3.2 LITER',
#        'Engine: Direct-Injection Turbocharged', '2.0T',
#        'Electric 402hp 486ft. lbs.'], dtype=object)

# %% [markdown]
# The majority of the above listed are electric or hybrid engines

# %%
df[df['engine_cylinders'].isnull()].groupby(['engine'], dropna=False).size().reset_index(name='Count').sort_values(by='Count', ascending=False).head(50)
# Out:
#                                                 engine  Count
# 513                                                Gas   3382
# 412                                           Electric   3195
# 558                                          Turbo Gas   2716
# 471                                     Electric Motor   2695
# 578                                                  –   1115
# 517                                             Hybrid    293
# 539                                     Plug-in Hybrid    149
# 409                                     ELECTRIC MOTOR    128
# 520                                   L Electric Motor     74
# 387                            Dual AC Electric Motors     66
# 86                                                2.0L     64
# 408                                           ELECTRIC     59
# 560                                 Turbo Supercharged     57
# 371                                  AC Electric Motor     54
# 117                                  2.0L Turbocharged     54
# 469                                Electric Drive Unit     53
# 1                                                  0.0     50
# 141                                               2.5L     41
# 557                                       Turbo Diesel     40
# 535                                      Not Specified     39
# 219                                               3.6L     38
# 559                                       Turbo Hybrid     37
# 3                                                 0.0L     35
# 186                                               3.0L     34
# 90                                       2.0L 16V DOHC     33
# 207                                               3.5L     31
# 298        425.0HP Electric Motor Electric Fuel System     28
# 99                                           2.0L DOHC     25
# 392                               Dual Electric Motors     23
# 383  DUAL MOTOR FR AC INDUCTION/RR AC PERMANENT MAGNET     23
# 551                                   Supercharged Gas     20
# 438                         Electric 346hp 389ft. lbs.     20
# 83                                               2.0 L     18
# 174        271.0HP Electric Motor Electric Fuel System     18
# 395  Dual Motor: Fr AC Induction/Rr AC Permanent Ma...     18
# 114                                      2.0L TSI DOHC     17
# 330        518.0HP Electric Motor Electric Fuel System     17
# 93                            2.0L 16V TwinPower Turbo     16
# 304        455.0HP Electric Motor Electric Fuel System     15
# 404                                  ECOTEC 1.3L Turbo     15
# 264                                                  4     15
# 137                                                2.5     14
# 38                                                1.6L     14
# 82                                                 2.0     14
# 562                                  Turbocharged 1.3/     14
# 29                                           1.5L DOHC     13
# 199                                               3.3L     11
# 217                                              3.6 L     11
# 478                                       Electric ZEV     11
# 26                                                1.5L     10

# %% [markdown]
# #### Engine Horse Power

# %% [markdown]
# En algunos vehículos, se encuentra información sobre los caballos de fuerza, medidos en HP o kW.

# %% [markdown]
# Some vehicles provide information about horsepower, measured in HP or kW.

# %%
def get_left_hand_side_hp(text):
    # Get the number on the left hand-side of the text if any
    text=text.replace(',','')
    result=""
    already_found_dot=False
    for char in text[::-1]:
        if char.isdigit():
            result = char + result
        elif char == '.' and not already_found_dot:
            result = char + result
            already_found_dot=True   
        else:
            break  # Stop when we encounter a non-number, non-dot character, or a second dot
    return result


def get_engine_HP(text):
    possible_splitters=['HP', 'KW']
    for splitter in possible_splitters:
        for i in range(text.upper().count(splitter)):
            #Evaluate if there is a number in the left hand side of the splitters associated to horse power
            horse_power=get_left_hand_side_hp(text.upper().split(splitter)[i].strip())
            if horse_power.replace('.', '', 1).isdigit() and horse_power.count('.')< 2:
                if splitter=='KW':
                    return float(horse_power)*1.34102 # Convert KW to HP
                else: 
                    return float(horse_power)
                
    # Find all the numbers (including decimals) in the string
    numbers = re.findall(r'\d+\.?\d*', text)
    numbers = [float(num) if '.' in num else int(num) for num in numbers]
    sorted_numbers = sorted(numbers, reverse=True)
    for number in sorted_numbers: 
        # We assume that the HP is the greatest number between 60 and 1200
        # that is not surrounded by a volume unit
        if 60<=number<=500:
            i=text.find(str(number))
            j=i+len(str(number))
            is_HP=True
            possible_other_units = ['CI', 'ci','c.i.','CC', 'cc']
            for unit in possible_other_units:
                if unit in text[j:j+6]:
                    is_HP=False
                    break
                if unit in text[i-6:i]:
                    is_HP=False
                    break
            if is_HP:
                return number
    return None

df['engine_HP']=df['engine'].apply(get_engine_HP)

# %%
# Check nulls in engine_HP: Taking a sample of the null values, it seams that non of them have information about the power of the car
df[df['engine_HP'].isnull()]['engine'].unique()[:60]
# Out:
# array(['2.4L I-4 DOHC, i-VTEC variable valve control, premium unleaded,',
#        '2L I-4 gasoline direct injection, DOHC, VTEC variable valve cont',
#        '3.5L V-6 gasoline direct injection, i-VTEC variable valve contro',
#        '1.5L I-4 gasoline direct injection, DOHC, VTEC variable valve co',
#        '3.5L V-6 i-VTEC variable valve control, premium unleaded, engine',
#        '2.4L I4', '3.5L V6 24V GDI SOHC',
#        '3.5L V-6 gasoline direct injection, variable valve control, prem',
#        '3.0L PGM-FI 24V SOHC i-VTEC V6 -inc: Variable Cylinder Managemen',
#        'Gas', '2.0L I4 16V GDI DOHC Turbo', '3.5L V6 SOHC 24V',
#        'Electric', 'Turbo Gas',
#        '3L V-6 i-VTEC variable valve control, premium unleaded, engine w',
#        '2.4L I-4 gasoline direct injection, DOHC, i-VTEC variable valve',
#        '3.5L V6 24V MPFI SOHC',
#        '3.2L V-6 variable valve control, premium unleaded, engine with 2',
#        '3.5L V-6 variable valve control, premium unleaded, engine with 2',
#        '3.5L V-6 gasoline direct injection, i-VTEC VCM variable valve co',
#        '3.5L V-6 VTEC variable valve control, premium unleaded, engine w',
#        '2.4L I4 16V MPFI DOHC', '3.7L V6 24V MPFI SOHC',
#        '3.7L V-6 VTEC variable valve control, premium unleaded, engine w',
#        '2.4L I4 16V GDI DOHC', '2.0L I4 16V MPFI SOHC',
#        '2.3L I4 16V MPFI DOHC Turbo', '4 Cylinder Engine',
#        '2L I-4 i-VTEC variable valve control, premium unleaded, engine w',
#        '3.5L V-6 port/direct injection, DOHC, VTC variable valve control',
#        '3.0L V6 24V MPFI SOHC Hybrid', '3.0L V6 24V GDI DOHC Turbo',
#        '2.4L DOHC 16-Valve VTEC 4-Cylinder', '–', '2.4L DOHC 16V',
#        '2.0L I4',
#        '3L V-6 gasoline direct injection, DOHC, i-VTEC variable valve co',
#        '1.5L I-4 i-VTEC variable valve control, premium unleaded, engine',
#        '2.0L I4 16V MPFI DOHC', '3.5L V6', '1.5L I4 16V GDI DOHC Turbo',
#        '3.7L V6 SOHC VTEC',
#        '2L I-4 DOHC, variable valve control, regular unleaded, engine wi',
#        '2.4L I4 DOHC i-VTEC 16V',
#        '3L NA V6 single overhead cam (SOHC) 24V',
#        '2L I-4 gasoline direct injection, DOHC, variable valve control,',
#        '3.2L V-6 VTEC variable valve control, premium unleaded, engine w',
#        '3.2L V6 24V MPFI SOHC', '4 Cylinder',
#        '2.4L I-4 gasoline direct injection, DOHC, variable valve control',
#        '3L V-6 gasoline direct injection, DOHC, variable valve control,',
#        '3.5L V6 SOHC i-VTEC 24V', '2.0L 16V DOHC', '3.7L V6', '2.4L',
#        '3.5L', '6 Cylinder', '3.5L V6 24V GDI SOHC Hybrid',
#        '2.4L 4 Cylinder Engine', '3.5L V6    F SOHC 24V'], dtype=object)

# %%
#The number of missing values is really high
df.groupby(['engine_HP'], dropna=False).size().reset_index(name='Count')
# Out:
#      engine_HP   Count
# 0         60.0       1
# 1         61.0       1
# 2         62.0      10
# 3         63.0       1
# 4         70.0      22
# ..         ...     ...
# 397      834.0       7
# 398      845.0       5
# 399     1000.0       1
# 400     1020.0      11
# 401        NaN  133814
#
# [402 rows x 2 columns]

# %%
# We remove the original variable
df.drop(columns=['engine'], inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  mileage interior_color  \
# 0              2006     19  acura    76497          Biege
# 1              2021      4  acura    54931       Espresso
# 2              2017      8  acura   103720          Ebony
# 3              2024      1  acura    17309          Ebony
# 4              2017      8  acura    66552          Ebony
#
#           exterior_color fuel_type  price_USD  \
# 0            Green Pearl  Gasoline    10995.0
# 1   Majestic Black Pearl  Gasoline    27985.0
# 2  Modern Steel Metallic  Gasoline    17981.0
# 3   Platinum White Pearl  Gasoline    30049.0
# 4    White Diamond Pearl  Gasoline    18950.0
#
#                                                  url  mpg_city  ...  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0  ...
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0  ...
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0  ...
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0  ...
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0  ...
#
#    num_speeds  transmission_type        drive_train stock_type    model  \
# 0         NaN          Automatic  Front-wheel Drive       Used      TSX
# 1        10.0          Automatic    All-wheel Drive       Used      RDX
# 2         NaN          Automatic    All-wheel Drive       Used      MDX
# 3         NaN          Automatic  Front-wheel Drive       Used  INTEGRA
# 4         NaN          Automatic    All-wheel Drive       Used      RDX
#
#   vehicle_type engine_displacement  engine_cylinders  engine_HP  fuel_type_v2
# 0      Compact                 2.4               4.0        NaN      Gasoline
# 1          SUV                 2.0               4.0        NaN      Gasoline
# 2          SUV                 3.5               6.0        NaN      Gasoline
# 3      Compact                 1.5               4.0        NaN      Gasoline
# 4          SUV                 3.5               6.0        NaN      Gasoline
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Fuel type

# %% [markdown]
# En aras de la simplicidad, consideramos que hay solo cinco categorías de tipo de motorización: eléctrico (cuando el tipo de combustible no está informado), gasolina, diesel, híbrido y gas (incluye E85 y gas natural)

# %% [markdown]
# For the sake of simplicity, we only consider 5 categories: Electric (fuel type not informed), Gasoline, Diesel, Hybrid and Gas (includes E85 and natural gas)

# %%
df.loc[df['fuel_type'].apply(lambda x: isinstance(x, float) and np.isnan(x)),'fuel_type']=None # substitue NaN for None
df.loc[df['fuel_type'] == '–', 'fuel_type'] = None


def get_fuel_type(text):
    if text is None:
        return 'Electric'
    if "HYBRI" in text.upper():
        return "Hybrid"
    if "GASOL" in text.upper() or "UNLEADED" in text.upper():
        return "Gasoline"
    if "DIESEL" in text.upper():
        return "Diesel"
    if "GAS" in text.upper() or 'E85' in text.upper():
        return "Gas"
    return None

df['fuel_type_v2']=df['fuel_type'].apply(get_fuel_type)
df['fuel_type'].unique()
# Out:
# array(['Gasoline', None, 'Hybrid', 'E85 Flex Fuel', 'Gas',
#        'Plug-In Hybrid', 'Diesel', 'Flexible Fuel',
#        'Gasoline / Natural Gas', 'Gasoline fuel type',
#        'Gasoline/Mild Electric Hybrid', 'Plug-in Gas/Electric Hybrid',
#        'Other', 'Diesel (B20 capable)', 'Unspecified', 'Gaseous', 'Flex',
#        'Plug-In Hybrid Fuel', 'Regular Unleaded',
#        'Compressed Natural Gas', 'Natural Gas', 'Gasoline Fuel',
#        'Premium Unleaded', 'Plug-in Hybrid Electric (PHEV)',
#        'PHEV (plug-in hybrid electric vehicle)', 'PHEV Hybrid Fuel',
#        'mild', 'MHEV (mild hybrid electric vehicle)',
#        'Gasoline/Mild Electric Hybri'], dtype=object)

# %%
# Check nulls in fuel_type_v2: All null values in fuel_type_v2 are due to the fact that fuel_type variable doesn't provide the information
df[df['fuel_type_v2'].isnull()]['fuel_type'].unique()
# Out:
# array(['Flexible Fuel', 'Other', 'Unspecified', 'Flex', 'mild'],
#       dtype=object)

# %% [markdown]
# En la siguiente tabla se muestra cómo se mapea el tipo de combustible, según la variable original, a la variable procesada.

# %% [markdown]
# The following table shows how the fuel type is mapped from the original variable to the processed variable.

# %%
df.groupby(['fuel_type','fuel_type_v2'], dropna=False).size().reset_index(name='Count')
# Out:
#                                  fuel_type fuel_type_v2   Count
# 0                   Compressed Natural Gas          Gas       2
# 1                                   Diesel       Diesel    2880
# 2                     Diesel (B20 capable)       Diesel       4
# 3                            E85 Flex Fuel          Gas    1492
# 4                                     Flex          NaN       1
# 5                            Flexible Fuel          NaN      11
# 6                                      Gas          Gas      20
# 7                                  Gaseous          Gas       6
# 8                                 Gasoline     Gasoline  122148
# 9                   Gasoline / Natural Gas     Gasoline      27
# 10                           Gasoline Fuel     Gasoline       1
# 11                      Gasoline fuel type     Gasoline      13
# 12            Gasoline/Mild Electric Hybri       Hybrid       1
# 13           Gasoline/Mild Electric Hybrid       Hybrid      15
# 14                                  Hybrid       Hybrid    5593
# 15     MHEV (mild hybrid electric vehicle)       Hybrid       1
# 16                             Natural Gas          Gas       1
# 17                                   Other          NaN      20
# 18  PHEV (plug-in hybrid electric vehicle)       Hybrid       1
# 19                        PHEV Hybrid Fuel       Hybrid       1
# 20                          Plug-In Hybrid       Hybrid     197
# 21                     Plug-In Hybrid Fuel       Hybrid       3
# 22             Plug-in Gas/Electric Hybrid       Hybrid       2
# 23          Plug-in Hybrid Electric (PHEV)       Hybrid       1
# 24                        Premium Unleaded     Gasoline       5
# 25                        Regular Unleaded     Gasoline       6
# 26                             Unspecified          NaN      10
# 27                                    mild          NaN       1
# 28                                     NaN     Electric    8722

# %%
# We remove the original variable and substitute it for the processed one
df.drop(columns=['fuel_type'], inplace=True)
df.rename(columns={'fuel_type_v2': 'fuel_type'}, inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  mileage interior_color  \
# 0              2006     19  acura    76497          Biege
# 1              2021      4  acura    54931       Espresso
# 2              2017      8  acura   103720          Ebony
# 3              2024      1  acura    17309          Ebony
# 4              2017      8  acura    66552          Ebony
#
#           exterior_color  price_USD  \
# 0            Green Pearl    10995.0
# 1   Majestic Black Pearl    27985.0
# 2  Modern Steel Metallic    17981.0
# 3   Platinum White Pearl    30049.0
# 4    White Diamond Pearl    18950.0
#
#                                                  url  mpg_city  mpg_highway  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0         31.0
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0         27.0
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0         26.0
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0         36.0
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0         27.0
#
#    num_speeds transmission_type        drive_train stock_type    model  \
# 0         NaN         Automatic  Front-wheel Drive       Used      TSX
# 1        10.0         Automatic    All-wheel Drive       Used      RDX
# 2         NaN         Automatic    All-wheel Drive       Used      MDX
# 3         NaN         Automatic  Front-wheel Drive       Used  INTEGRA
# 4         NaN         Automatic    All-wheel Drive       Used      RDX
#
#   vehicle_type  engine_displacement  engine_cylinders  engine_HP fuel_type
# 0      Compact                  2.4               4.0        NaN  Gasoline
# 1          SUV                  2.0               4.0        NaN  Gasoline
# 2          SUV                  3.5               6.0        NaN  Gasoline
# 3      Compact                  1.5               4.0        NaN  Gasoline
# 4          SUV                  3.5               6.0        NaN  Gasoline

# %% [markdown]
# #### Color

# %% [markdown]
# En el conjunto de datos se dispone del color interior y exterior del vehículo, expresado en lenguaje natural. Sin embargo, las descripciones asociadas a estos colores son, en muchos casos, no estándar, creativas o ambiguas. Para que estas variables puedan ser utilizadas en el modelo, es imprescindible codificarlas mediante el sistema RGB, que asigna a cada color tres valores enteros entre 0 y 255, correspondientes a su composición en términos de la intensidad de los colores primarios (rojo, verde y azul).
#
# Para un modelo de aprendizaje automático, la codificación RGB es mucho más útil que una codificación categórica en colores, dado que el número de valores posibles que puede tomar la variable categórica es muy elevado. Con la codificación RGB, se pueden cuantificar las relaciones entre las diferentes tonalidades de los colores. Por ejemplo, (100, 50, 0) es marrón oscuro, (200, 100, 0) es marrón claro y (150, 75, 0) es marrón. Mientras que medir la similitud de cadenas de texto puede ser complicado, comparar vectores en un espacio tridimensional es mucho más sencillo.
#
# Para etiquetar los datos, es decir, asignar a cada color en lenguaje natural su codificación RGB, se ha utilizado un modelo LLM con el objetivo de agilizar una tarea rutinaria y fácilmente automatizable. El prompt utilizado se puede encontrar [aquí](https://github.com/jcllanu/residual-value/blob/main/color_codification_prompt.txt), y el modelo LLM empleado es el 3o mini de ChatGPT con la opción "Razona" activada. De manera manual, se ha verificado que esta codificación es coherente para una muestra reducida. Para ello, se ha utilizado la siguiente [macro](https://github.com/jcllanu/residual-value/blob/main/excel_color_macro.txt) de Excel, que rellena las celdas del color indicado por la codificación RGB. A pesar de la dificultad de la tarea, debido a la ambigüedad en muchas de las descripciones de los colores en lenguaje natural, los resultados obtenidos por el modelo LLM son bastante satisfactorios.

# %% [markdown]
# The dataset includes both the interior and exterior colors of the vehicle, expressed in natural language. However, the descriptions associated with these colors are, in many cases, non-standard, creative, or ambiguous. To make these variables usable in the model, it is essential to encode them using the RGB system, which assigns three integer values between 0 and 255 to each color, corresponding to its composition in terms of the intensity of the primary colors (red, green, and blue).
#
# For a machine learning model, RGB encoding is much more useful than categorical color encoding, as the number of possible values the categorical variable can take is very high. With RGB encoding, the relationships between different color shades can be quantified. For example, (100, 50, 0) is dark brown, (200, 100, 0) is light brown, and (150, 75, 0) is brown. While measuring the similarity of text strings can be difficult, comparing vectors in a three-dimensional space is much easier.
#
# To label the data, i.e., to assign the RGB encoding to each color in natural language, an LLM model was used to streamline a routine and easily automatable task. The prompt used can be found [here](https://github.com/jcllanu/residual-value/blob/main/color_codification_prompt.txt), and the LLM model employed is the 3o mini of ChatGPT with the "Reason" option activated. Manual verification was carried out to ensure the consistency of the encoding for a reduced sample. For this, the following Excel [macro](https://github.com/jcllanu/residual-value/blob/main/excel_color_macro.txt) was used to fill in the cells with the RGB color encoding. Despite the difficulty of the task, due to the ambiguity in many of the natural language color descriptions, the results obtained by the LLM are quite satisfactory.

# %%
# List of all possible interior and exterior colors
color_list=list(set((list(df['interior_color'])+list(df['exterior_color']))))
sorted_color_list=sorted(color_list)
print(len(sorted_color_list))
sorted_color_list[1000:1500]
# Out:
# 9872
# ['Black Blue Vescin/Cl Tcb2',
#  'Black Bordeaux Red',
#  'Black CLoth',
#  'Black Carbon',
#  'Black Ceramique',
#  'Black Chalk',
#  'Black Cherry',
#  'Black Cherry Metallic',
#  'Black Cherry Mica',
#  'Black Cherry Pearl',
#  'Black Clear Coat',
#  'Black Clear Coat Px8',
#  'Black Clear Coat/White Gold Clear Coat',
#  'Black Clearcoat',
#  'Black Clearcoat / Black Cloth Top',
#  'Black Clearcoat/Black Cloth Top',
#  'Black Clearcoat/Black Soft Top',
#  'Black Clearcoat/Bright Silver Metallic Clearcoat',
#  'Black Cloth',
#  'Black Cloth Interior',
#  'Black Cloth with Orange Stitching',
#  'Black Cloudtex & Cloth',
#  'Black Cloudtex Leatherette & Cloth',
#  'Black Copper',
#  'Black Copper Pearl',
#  'Black Currant Metallic',
#  'Black DINAMICA',
#  'Black DINAMICA w/Red',
#  'Black Dakota',
#  'Black Dakota Leather',
#  'Black Dakota, leather',
#  'Black Diamond',
#  'Black Diamond Mica',
#  'Black Diamond P',
#  'Black Diamond Pearl',
#  'Black Diamond Tri-Coat',
#  'Black Diamond Tricoat',
#  'Black Diamond/Alloy Silver Roof',
#  'Black Diamond/Deep Bronze Metallic',
#  'Black Ea20',
#  'Black Exclusive Nappa Leather',
#  'Black Extended High Performance Leather',
#  'Black Extended Merino',
#  'Black Fabric',
#  'Black Fb20',
#  'Black Flare Re',
#  'Black Forest Green Pearl',
#  'Black Forest Green Pearlcoat',
#  'Black Forest Pearl',
#  'Black Full Leather',
#  'Black Gold Pearlcoat',
#  'Black Granite Metallic',
#  'Black Granite Pearl',
#  'Black Granite Pearl/Titanium Pearl',
#  'Black Graphite',
#  'Black Gray',
#  'Black Heated Leather',
#  'Black Ice',
#  'Black Ice Metallic',
#  'Black Ice Metallic 58u',
#  'Black In3pb',
#  'Black Ink',
#  'Black Interior',
#  'Black Interior/ Red Stitching',
#  'Black Kcsw',
#  'Black Leather',
#  'Black Leather (Stitching In Guards Red)',
#  'Black Leather (an)',
#  'Black Leather Inter',
#  'Black Leather Interior',
#  'Black Leather Trim Bucket Seat',
#  'Black Leather Trimmed',
#  'Black Leather With Naguri Aluminum Trim',
#  'Black Leather w/ Red Accents',
#  'Black Leather with Suede Inserts',
#  'Black Leather-Trimmed',
#  'Black Leatherette',
#  'Black Leatherweave',
#  'Black Lthr W/ Yellow Accents',
#  'Black Luxor Beige',
#  'Black MB Tex',
#  'Black MB-Tex',
#  'Black MB-Tex / Microfiber w/ Red Stitching',
#  'Black MB-Tex with Dinamica',
#  'Black MB-Tex/Microfiber with Red Stitching',
#  'Black Mb-Tex',
#  'Black Metallic',
#  'Black Mica',
#  'Black Nappa',
#  'Black Nappa Lea',
#  'Black Nappa Leather',
#  'Black Nappa/Dinamica Exclusive with Yellow contrast Stitch',
#  'Black Nappa/Red',
#  'Black Nasca',
#  'Black Noir Pearl',
#  'Black Noir Pearl Mica',
#  'Black Novillo',
#  'Black Novillo Leather Interior',
#  'Black NuLuxe with Matte W',
#  'Black NuLuxe with Scored',
#  'Black Nuluxe',
#  'Black Nuluxe Black Wa',
#  'Black Nuluxe Dark Gra',
#  'Black Nuluxe Hadori A',
#  'Black Nuluxe Open Por',
#  'Black Nuluxe Stippled',
#  'Black Nuluxe With Black &',
#  'Black Nuluxe With Matte W',
#  'Black Nuluxe With Open-Po',
#  'Black Nuluxe&Amp; With Op',
#  'Black Nuluxe<sup></sup>[nuluxe] With Dark Umber Trim',
#  'Black Nv',
#  'Black Oak Brown',
#  'Black Oak Brown Metallic',
#  'Black Obsidian',
#  'Black Obsidian (kh3)',
#  'Black Obsidian Kh3',
#  'Black Onyx',
#  'Black Onyx Crystal Pearlcoat',
#  'Black Onyx Leather-trimmed/Vinyl',
#  'Black Onyx Pearl',
#  'Black Onyx Trim',
#  'Black Onyx metallic',
#  'Black Onyx w/Brandy Stitch',
#  'Black Onyx/Dark Slate',
#  'Black Onyx/Light Space Gray',
#  'Black Onyx/Medium Dark Slate',
#  'Black Onyx/Roast',
#  'Black Onyx/UCA76',
#  'Black Opal Metallic',
#  'Black Opal Mica',
#  'Black Oynx',
#  'Black Oynx W/Space Gray',
#  'Black Oynx w/Space Gray',
#  'Black Oynx with Medium Light Space Gray',
#  'Black Pbc',
#  'Black Pearl',
#  'Black Pearl (kde1)',
#  'Black Pearl Leather',
#  'Black Pearl Light Checkered',
#  'Black Pearl Light Chequered',
#  'Black Pearl Lt Checkered',
#  'Black Pearl Lt Chequered',
#  'Black Pearl/Black',
#  'Black Perforate',
#  'Black Perforated',
#  'Black Perforated Leather-Trimmed',
#  'Black Perforated Suede/evotex Seat Trim',
#  'Black Perforated Veganza',
#  'Black Pipe',
#  'Black Plus PVC',
#  'Black Preferred Suede and Leather Trim',
#  'Black Premium',
#  'Black Premium Leather',
#  'Black Quartz',
#  'Black Quilted Leather',
#  'Black Rave',
#  'Black Raven',
#  'Black Raven - GBA',
#  'Black Raven Gba',
#  'Black Rbp',
#  'Black Red',
#  'Black Red Cut',
#  'Black Roof/Moonlight',
#  'Black Ry',
#  'Black Sable Brown',
#  'Black Saddle / Tan',
#  'Black Sand Mica',
#  'Black Sand Pearl',
#  'Black Saphire',
#  'Black Sapphire',
#  'Black Sapphire Met',
#  'Black Sapphire Metallic',
#  'Black Sapphire Pearl',
#  'Black Semi-Aniline Leathe',
#  'Black Sensafin',
#  'Black Series Interior - Two Tone',
#  'Black Shetland',
#  'Black Softex]',
#  'Black Sport',
#  'Black Sport Seats',
#  'Black Standard',
#  'Black Stone',
#  'Black Stone [Black',
#  'Black Striated',
#  'Black Synthetic Leather',
#  'Black Tie',
#  'Black Top',
#  'Black Trim',
#  'Black Tuxedo',
#  'Black Uni',
#  'Black Uni/Black Roof',
#  'Black Valcona',
#  'Black Velvet',
#  'Black Velvet Metallic',
#  'Black Velvet/Black Velvet',
#  'Black Vernasca Leather',
#  'Black Vernasca Leather Upholstery',
#  'Black W',
#  'Black W Fabric Seating Surfaces',
#  'Black W RED STITCHING',
#  'Black W Red',
#  'Black W Seat Trim',
#  'Black W/ Black Grained Trim (ed20)',
#  'Black W/ Brown',
#  'Black W/ Gray',
#  'Black W/ Rock Gray Stitching (ao)',
#  'Black W/Beige Stitching',
#  'Black W/Blue Accents',
#  'Black W/Blue Stitching',
#  'Black W/Brown',
#  'Black W/Carmine Red, Leather Seat Trim W/Race Tex Centers & GTS',
#  'Black W/Contrast',
#  'Black W/Contrast Stitch',
#  'Black W/Linear Espresso W',
#  'Black W/M Color Highlight',
#  'Black W/Medium Dark Slate',
#  'Black W/Mercato Blue',
#  'Black W/Orange Stitching',
#  'Black W/Oyster Stitching',
#  'Black W/Premium Seat Trim',
#  'Black W/Red Accent Stitching',
#  'Black W/Red Hi/Stitch',
#  'Black W/Red Highlight',
#  'Black W/Red Stitching',
#  'Black W/Stitching',
#  'Black W/Striated Black Trim',
#  'Black W/crescendo Red',
#  'Black W/red Highlight',
#  'Black W/red Stitching',
#  'Black With Blue Accents',
#  'Black With Orange Stitching Bo',
#  'Black With Red Accents Evotex Seat Trim',
#  'Black Wk',
#  'Black Wk1',
#  'Black Woven Cloth, cloth',
#  'Black X3',
#  'Black X9',
#  'Black Y',
#  'Black [Black]',
#  'Black and Blue',
#  'Black and Brown',
#  'Black and Cashmere Full Leather',
#  'Black and Cream w/ Carbon Fiber',
#  'Black and Gray',
#  'Black and Orange',
#  'Black and Red',
#  'Black and White',
#  'Black and White Synthetic Leather',
#  'Black and White w/ Carbon Fiber',
#  'Black and carbon fiber trim everywhere.',
#  'Black convertible top',
#  'Black leather',
#  'Black seat trim',
#  'Black w Extended Merino Leather Upholstery',
#  'Black w Gray Stitching',
#  'Black w Perforated Sensatec Upholstery',
#  'Black w Red Stitching',
#  'Black w Rock Gray Stitch',
#  'Black w Shark Blue Stitch',
#  'Black w Vernasca Leather Upholstery',
#  'Black w/ Arctic Grey Stitching',
#  'Black w/ Black Cascade Trim',
#  'Black w/ Black Grained Trim',
#  'Black w/ Blue Crust',
#  'Black w/ Blue Stitching',
#  'Black w/ Carbon Fiber',
#  'Black w/ Carmine Red Stitching',
#  'Black w/ Chalk Stitching',
#  'Black w/ Contrast Stitching',
#  'Black w/ Deep Sea Blue',
#  'Black w/ Deviated Arctic Grey Stitching',
#  'Black w/ Deviated Neodyme Stitching',
#  'Black w/ GT Silver Stitching',
#  'Black w/ Guards Red Stitching',
#  'Black w/ M Color Highlight',
#  'Black w/ Mercato Blue Stitching',
#  'Black w/ Midrand Beige Stitching',
#  'Black w/ Orange',
#  'Black w/ Orange Stitching',
#  'Black w/ Red Contrast Diamond Stitching',
#  'Black w/ Red Stitching',
#  'Black w/ Rock Gray Stitching',
#  'Black w/ Silver Crust',
#  'Black w/Alcantara',
#  'Black w/Alcantara w/Premium Milano Leather-Trimmed',
#  'Black w/Alloy & Black Stitch',
#  'Black w/Arctic',
#  'Black w/Arctic Gray Stitching',
#  'Black w/Arctic Grey',
#  'Black w/Artic Grey',
#  'Black w/Atlas Grey',
#  'Black w/Atlas Grey M',
#  'Black w/Baja Tan',
#  'Black w/Bamboo',
#  'Black w/Beige Stitch',
#  'Black w/Beige Stitching',
#  'Black w/Birds Eye Maple',
#  'Black w/Black',
#  'Black w/Black Cascade Trim',
#  'Black w/Black Geometric Trim',
#  'Black w/Black Leather',
#  'Black w/Black Metallic',
#  'Black w/Black Open Pore',
#  'Black w/Black Top',
#  'Black w/Blue',
#  'Black w/Blue Conrtast Stitching',
#  'Black w/Blue Contrast Stitching',
#  'Black w/Blue Contrast Stitching/Piping',
#  'Black w/Blue Stitch',
#  'Black w/Blue Stitching',
#  'Black w/Brown',
#  'Black w/Carmine Red',
#  'Black w/Chalk Stitching',
#  'Black w/Channel Design',
#  'Black w/Circle Design',
#  'Black w/Contrast Stitch/Piping',
#  'Black w/Contrast Stitching',
#  'Black w/Copper Stitching',
#  'Black w/Crescendo Red',
#  'Black w/Crescendo Red Stitching',
#  'Black w/Dark Graphite',
#  'Black w/Dark Graphite -',
#  'Black w/Dark Graphite Aluminum',
#  'Black w/Dark Oyster Highlight',
#  'Black w/Dark Silver Sttch',
#  'Black w/Dark Umber Trim',
#  'Black w/Deep Blue',
#  'Black w/Deep Sea Blue',
#  'Black w/Deep Sea Blue Stitching',
#  'Black w/Diamond Stitching',
#  'Black w/Exclusive Stitching',
#  'Black w/Express Red',
#  'Black w/Express Red Stitching',
#  'Black w/Fabric Seat Trim',
#  'Black w/GT Silver Stitch',
#  'Black w/Ginsumi',
#  'Black w/Gray',
#  'Black w/Gray Accent',
#  'Black w/Gray Bolsters',
#  'Black w/Gray Contrast Stitching',
#  'Black w/Gray-Brown Piping',
#  'Black w/Grey Accents',
#  'Black w/Grey Stitching',
#  'Black w/Guards Red Stitch',
#  'Black w/Guards Red Stitching',
#  'Black w/Hadori Aluminum',
#  'Black w/Hadori Aluminum Trim',
#  'Black w/Korso Red',
#  'Black w/Lapis & Blue Carbon',
#  'Black w/Leather Pkg',
#  'Black w/Leather Seat Trim',
#  'Black w/Light Diesel Grey Stitching',
#  'Black w/Lime',
#  'Black w/Linear Black Shadow Wood Trim',
#  'Black w/Linear Espresso Wood',
#  'Black w/Linear Espresso Wood Trim',
#  'Black w/Linear Wood',
#  'Black w/M Color Highlight',
#  'Black w/Medium Dark Slate',
#  'Black w/Micrommata Green',
#  'Black w/Midrand Beige',
#  'Black w/Midrand Beige Contrast Stitching',
#  'Black w/Orange Stitching',
#  'Black w/Oyster Contrast Stitching',
#  'Black w/Oyster Stitching',
#  'Black w/Papaya Stitching',
#  'Black w/Pebble Beige Stitch',
#  'Black w/Piano Black',
#  'Black w/Premium Cloth Low-Back Bucket Seats or Lea',
#  'Black w/Premium Cloth Seating Surfaces',
#  'Black w/Racing Yellow w/Leather Seat Trim w/Sport-Tex Centers &',
#  'Black w/Red',
#  'Black w/Red Accents',
#  'Black w/Red Contrast Topstitching',
#  'Black w/Red Hi/Stitch',
#  'Black w/Red Highlight',
#  'Black w/Red Highlight/Stitching',
#  'Black w/Red Stitch',
#  'Black w/Red Stitching',
#  'Black w/Red Topstitching',
#  'Black w/Red/Grey Contrast Stitching & Red Accents',
#  'Black w/Rock Gray',
#  'Black w/Rock Gray Contrast Stitching',
#  'Black w/Rock Gray Stitch',
#  'Black w/Rock Gray Stitching',
#  'Black w/Ruby Red Accent Stitching',
#  'Black w/Sakhir Orange',
#  'Black w/Satin Chrome Trim',
#  'Black w/Satin Metallic Trim',
#  'Black w/Shimamoku',
#  'Black w/Silver',
#  'Black w/Silver Contrast Stitching',
#  'Black w/Silver Fiber',
#  'Black w/Silver Performance',
#  'Black w/Silver Performance Trim',
#  'Black w/Silver Stitching',
#  'Black w/Striated Black Trim',
#  'Black w/Vintage Brown',
#  'Black w/White Perforations and Genuine Aluminum Trim',
#  'Black w/White Stitching',
#  'Black w/Yacht Blue Stitch',
#  'Black w/Yellow',
#  'Black w/Yellow Contrast Stitching',
#  'Black w/Yellow Stitching',
#  'Black with Chalk Stitching',
#  'Black with Contrast Stitching',
#  'Black with Dark Silver Stitching',
#  'Black with Deviated Chalk Stitching',
#  'Black with Deviated Stitching in Guards Red',
#  'Black with Luxor Beige Stitching',
#  'Black with Red Accent Surfaces',
#  'Black with Rock Gray Stitching',
#  'Black**COMFORT PKG**SPORT PKG**WELL MAINTAINED**',
#  'Black**PANORAMIC ROOF**NAVIGATION SYSTEM**AWD',
#  'Black, Leather',
#  'Black, leather',
#  'Black-Saddle Tan',
#  'Black/ Silver',
#  'Black/Adrenaline Red',
#  'Black/Alcantara',
#  'Black/Alloy',
#  'Black/Alloy Cloth',
#  'Black/Alloy w/Black Stitch',
#  'Black/Alloy/Black',
#  'Black/Ara Blue Stitching',
#  'Black/Atlas Grey',
#  'Black/Barrique',
#  'Black/Barrique Red',
#  'Black/Beige',
#  'Black/Birch',
#  'Black/Biscaya Blue',
#  'Black/Black',
#  'Black/Black Leather',
#  'Black/Black Roof',
#  'Black/Black/Black',
#  'Black/Blackberry',
#  'Black/Blue',
#  'Black/Blue Highlight',
#  'Black/Blue Stitching',
#  'Black/Bordeaux',
#  'Black/Bordeaux Full Leather',
#  'Black/Bordeaux Red',
#  'Black/Bronze',
#  'Black/Brown',
#  'Black/Cabernet',
#  'Black/Caramel',
#  'Black/Carbon',
#  'Black/Carbon Black',
#  'Black/Carbon Black Bolsters',
#  'Black/Carmine Red',
#  'Black/Carmine Red Stitching',
#  'Black/Carrara White',
#  'Black/Carrera Red',
#  'Black/Cattle Tan',
#  'Black/Chalk',
#  'Black/Chalk Leather',
#  'Black/Chalk Stitching',
#  'Black/Chamois Accent',
#  'Black/Classic Red',
#  'Black/Cohiba Brown',
#  'Black/Cool Grey',
#  'Black/Dark Marsala',
#  'Black/Dark Olive',
#  'Black/Dark Oyster',
#  'Black/Dark Saddle Interior',
#  'Black/Dark Sienna Brown',
#  'Black/Deep Green',
#  'Black/Deep Mocha',
#  'Black/Diesel',
#  'Black/Diesel Gray',
#  'Black/Diesel Gray (x8)',
#  'Black/Diesel Gray Interior',
#  'Black/Diesel Gray X8',
#  'Black/Digital White MB-Tex',
#  'Black/Excl. Stitch',
#  'Black/Express Red Stitch',
#  'Black/Express Red Stitching',
#  'Black/Film',
#  'Black/GT Silver',
#  'Black/Garnet',
#  'Black/Garnet Red',
#  'Black/Graphite',
#  'Black/Gray',
#  'Black/Grey',
#  'Black/Grey/White',
#  'Black/Guards Red',
#  'Black/Gun Metal',
#  'Black/Header Red',
#  'Black/Heritage Tan',
#  'Black/Iceland Gray',
#  'Black/Ivory',
#  'Black/Jet Gray',
#  'Black/Kalahari Grey',
#  'Black/LT Tungsten',
#  'Black/Lava Blue',
#  'Black/Lava Orange',
#  'Black/Light Diesel Gray',
#  'Black/Light Frost',
#  'Black/Light Frost Beige']

# %%
#Load the data
ini=0
fin=499
df_list=[]
for _ in range(20):
    path='colors/colors_'+str(ini)+'_'+str(fin)+'.csv'
    df_list.append(pd.read_csv(path, delimiter=';'))
    ini+=500
    fin+=500
df_list.append(pd.read_csv('colors/other_colors.csv', delimiter=';'))

df_color_dictionary=pd.concat(df_list, ignore_index=True,axis=0)[['Color','R','G','B']]

#Include some colors manually due to CSV condification problems
df_auxiliar = pd.DataFrame({'Color': ["'", 'Ebony &#47; Terracotta', 'N/A', 'None', 'null'],
        'R': [None, 80, None, None, None,],
        'G': [None, 40, None, None, None,],
        'B': [None, 20, None, None, None,]})

df_color_dictionary=pd.concat([df_auxiliar, df_color_dictionary], ignore_index=True,axis=0)
df_color_dictionary.tail(20)
# Out:
#                                                   Color      R      G      B
# 9864                                          Blue Grey  119.0  136.0  153.0
# 9865                                           Blue Ice  173.0  216.0  230.0
# 9866                                           Blue Ink    0.0    0.0   64.0
# 9867                             Brooklyn Grey Metallic  128.0  128.0  128.0
# 9868                                 Championship White  255.0  255.0  255.0
# 9869                                Creme Beige Leather  245.0  245.0  220.0
# 9870                        Dark Slate/Medium Graystone  105.0  105.0  105.0
# 9871                                Ice Silver Metallic  192.0  192.0  192.0
# 9872                                 Ice Storm Metallic  176.0  196.0  222.0
# 9873                        Iced Mocha Premium Colorant  210.0  180.0  140.0
# 9874  Includes (BQU) Dark Cocoa Ash Lower Accent Col...   92.0   64.0   51.0
# 9875                                    Ingot Blue Mica   65.0  105.0  225.0
# 9876  Jet Black With Cinnamon Accents, Leatherette S...   15.0   10.0   10.0
# 9877             Leather Interior in Black/Mojave Beige   80.0   70.0   60.0
# 9878                                           Magnetic  105.0  105.0  105.0
# 9879                              Modern Steel Metallic  119.0  136.0  153.0
# 9880                                                NaN  128.0  128.0  128.0
# 9881                                                NaN  128.0  128.0  128.0
# 9882                           White with Red Lettering  255.0  255.0  255.0
# 9883                                                NaN  128.0  128.0  128.0

# %%
print('Number of entries before the left joins:', len(df)) 

# Left join each natural language interior vehicle color to its RGB codification
df_color_dictionary.columns=['interior_color', 'R_interior', 'G_interior', 'B_interior']
df=pd.merge(df, df_color_dictionary, how='left', on='interior_color')

# Left join each natural language exterior vehicle color to its RGB codification
df_color_dictionary.columns=['exterior_color', 'R_exterior', 'G_exterior', 'B_exterior']
df=pd.merge(df, df_color_dictionary, how='left', on='exterior_color')

print('Number of entries after the left joins:', len(df))
# Out:
# Number of entries before the left joins: 141185
# Number of entries after the left joins: 141185

# %%
# We remove the original color variables
df.drop(columns=['interior_color', 'exterior_color'], inplace=True)
df.head()
# Out:
#    year_manufacture  years   make  mileage  price_USD  \
# 0              2006     19  acura    76497    10995.0
# 1              2021      4  acura    54931    27985.0
# 2              2017      8  acura   103720    17981.0
# 3              2024      1  acura    17309    30049.0
# 4              2017      8  acura    66552    18950.0
#
#                                                  url  mpg_city  mpg_highway  \
# 0  https://cars.com/vehicledetail/d6115b1a-3830-4...      22.0         31.0
# 1  https://cars.com/vehicledetail/f9548b93-31b2-4...      21.0         27.0
# 2  https://cars.com/vehicledetail/06e7a2fc-13ec-4...      18.0         26.0
# 3  https://cars.com/vehicledetail/658c133c-dc51-4...      29.0         36.0
# 4  https://cars.com/vehicledetail/79565df9-1fba-4...      19.0         27.0
#
#    num_speeds transmission_type  ... B_interior_x R_exterior_x G_exterior_x  \
# 0         NaN         Automatic  ...        220.0        144.0        238.0
# 1        10.0         Automatic  ...         20.0         20.0         20.0
# 2         NaN         Automatic  ...          0.0        119.0        136.0
# 3         NaN         Automatic  ...          0.0        255.0        255.0
# 4         NaN         Automatic  ...          0.0        255.0        255.0
#
#   B_exterior_x  R_interior_y  G_interior_y  B_interior_y R_exterior_y  \
# 0        144.0         245.0         245.0         220.0        144.0
# 1         20.0          80.0          40.0          20.0         20.0
# 2        153.0           0.0           0.0           0.0        119.0
# 3        255.0           0.0           0.0           0.0        255.0
# 4        255.0           0.0           0.0           0.0        255.0
#
#    G_exterior_y  B_exterior_y
# 0         238.0         144.0
# 1          20.0          20.0
# 2         136.0         153.0
# 3         255.0         255.0
# 4         255.0         255.0
#
# [5 rows x 30 columns]

# %%
# Save final df
df.to_excel('processed_dataset.xlsx', index=False)

# %%
# Missing percentage
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# year_manufacture        0.00
# years                   0.00
# make                    0.00
# model                   0.00
# mileage                 0.00
# stock_type              0.00
# interior_color          0.00
# exterior_color          0.00
# drive_train             0.00
# fuel_type               6.18
# transmission            0.00
# engine                  0.00
# price_USD               0.00
# url                     0.00
# mpg_city                9.83
# mpg_highway             9.83
# num_speeds             64.76
# transmission_type       0.47
# drive_train_v2          0.96
# stock_type_v2           0.00
# model_v2                0.00
# vehicle_type            0.00
# engine_displacement    11.68
# engine_cylinders       11.34
# engine_HP              94.78
# fuel_type_v2            0.03
# R_interior_x            0.01
# G_interior_x            0.01
# B_interior_x            0.01
# R_exterior_x            0.00
# G_exterior_x            0.00
# B_exterior_x            0.00
# R_interior_y            0.01
# G_interior_y            0.01
# B_interior_y            0.01
# R_exterior_y            0.00
# G_exterior_y            0.00
# B_exterior_y            0.00
# R_interior              0.01
# G_interior              0.01
# B_interior              0.01
# R_exterior              0.00
# G_exterior              0.00
# B_exterior              0.00
# dtype: float64
